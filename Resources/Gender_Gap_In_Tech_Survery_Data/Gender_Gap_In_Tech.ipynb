# %%
import pandas as pd

df = pd.read_csv("multiple_choice_responses.csv", index_col=False)
df.head()
# Out:
# C:\Users\snkty\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (0,3,7,19,34,47,49,50,51,52,53,54,68,81,94,96,109,115,130,139,147,154,167,180,193,206,219,232,245) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
# 1                                 510                        22-24
# 2                                 423                        40-44
# 3                                  83                        55-59
# 4                                 391                        40-44
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                    Male
# 2                                    Male
# ...

# %%
# Way too many columns
df = df[['Q1',
         'Q2', 
         'Q3',
         'Q4', 
         'Q5', 
         'Q6',
         'Q7',
         'Q8',
         'Q9_Part_1',
         'Q9_Part_2',
         'Q9_Part_3',
         'Q9_Part_4',
         'Q9_Part_5',
         'Q9_Part_6',
         'Q9_Part_7',
         'Q10',
         'Q11',
         'Q12_Part_1',
         'Q12_Part_2',
         'Q12_Part_3',
         'Q12_Part_4',
         'Q12_Part_5',
         'Q12_Part_6',
         'Q12_Part_7',
         'Q12_Part_8',
         'Q12_Part_9',
         'Q12_Part_10',
         'Q12_Part_11',
         'Q12_Part_12',
         'Q13_Part_1',
         'Q13_Part_2',
         'Q13_Part_3',
         'Q13_Part_4',
         'Q13_Part_5',
         'Q13_Part_6',
         'Q13_Part_7',
         'Q13_Part_8',
         'Q13_Part_9',
         'Q13_Part_10',
         'Q13_Part_11',
         'Q13_Part_12',
         'Q14',
         'Q16_Part_1',
         'Q16_Part_2',
         'Q16_Part_3',
         'Q16_Part_4',
         'Q16_Part_5',
         'Q16_Part_6',
         'Q16_Part_7',
         'Q16_Part_8',
         'Q16_Part_9',
         'Q16_Part_10',
         'Q16_Part_11',
         'Q16_Part_12',
         'Q17_Part_1',
         'Q17_Part_2',
         'Q17_Part_3',
         'Q17_Part_4',
         'Q17_Part_5',
         'Q17_Part_6',
         'Q17_Part_7',
         'Q17_Part_8',
         'Q17_Part_9',
         'Q17_Part_10',
         'Q17_Part_11',
         'Q17_Part_12',
         'Q18_Part_1',
         'Q18_Part_2',
         'Q18_Part_3',
         'Q18_Part_4',
         'Q18_Part_5',
         'Q18_Part_6',
         'Q18_Part_7',
         'Q18_Part_8',
         'Q18_Part_9',
         'Q18_Part_10',
         'Q18_Part_11',
         'Q18_Part_12',
         'Q19',
         'Q20_Part_1',
         'Q20_Part_2',
         'Q20_Part_3',
         'Q20_Part_4',
         'Q20_Part_5',
         'Q20_Part_6',
         'Q20_Part_7',
         'Q20_Part_8',
         'Q20_Part_9',
         'Q20_Part_10',
         'Q20_Part_11',
         'Q20_Part_12',
         'Q23',
         'Q24_Part_1',
         'Q24_Part_2',
         'Q24_Part_3',
         'Q24_Part_4',
         'Q24_Part_5',
         'Q24_Part_6',
         'Q24_Part_7',
         'Q24_Part_8',
         'Q24_Part_9',
         'Q24_Part_10',
         'Q24_Part_11',
         'Q24_Part_12',
         'Q25_Part_1',
         'Q25_Part_2',
         'Q25_Part_3',
         'Q25_Part_4',
         'Q25_Part_5',
         'Q25_Part_6',
         'Q25_Part_7',
         'Q25_Part_8',
         'Q27_Part_1',
         'Q27_Part_2',
         'Q27_Part_3',
         'Q27_Part_4',
         'Q27_Part_5',
         'Q27_Part_6',
         'Q28_Part_1',
         'Q28_Part_2',
         'Q28_Part_3',
         'Q28_Part_4',
         'Q28_Part_5',
         'Q28_Part_6',
         'Q28_Part_7',
         'Q28_Part_8',
         'Q28_Part_9',
         'Q28_Part_10',
         'Q28_Part_11',
         'Q28_Part_12',
         'Q32_Part_1',
         'Q32_Part_2',
         'Q32_Part_3',
         'Q32_Part_4',
         'Q32_Part_5',
         'Q32_Part_6',
         'Q32_Part_7',
         'Q32_Part_8',
         'Q32_Part_9',
         'Q32_Part_10',
         'Q32_Part_11',
         'Q32_Part_12']]

# %%
# Rename Columns 
df.columns = ['age',
              'gender',
              'country',
              'education',
              'job_title',
              'company_size',
              'Number_Ppl_in_Workload',
              'ML_avaliable_at_company',
           'Q9_Part_1',
         'Q9_Part_2',
         'Q9_Part_3',
         'Q9_Part_4',
         'Q9_Part_5',
         'Q9_Part_6',
         'Q9_Part_7',
         'Q9_Part_8',
              'Salary',
              'ML_expenses'
              'Q12_Part_1',
         'Q12_Part_2',
         'Q12_Part_3',
         'Q12_Part_4',
         'Q12_Part_5',
         'Q12_Part_6',
         'Q12_Part_7',
         'Q12_Part_8',
         'Q12_Part_9',
         'Q12_Part_10',
         'Q12_Part_11',
         'Q12_Part_12',
         'Q13_Part_1',
         'Q13_Part_2',
         'Q13_Part_3',
         'Q13_Part_4',
         'Q13_Part_5',
         'Q13_Part_6',
         'Q13_Part_7',
         'Q13_Part_8',
         'Q13_Part_9',
         'Q13_Part_10',
         'Q13_Part_11',
         'Q13_Part_12',
              'Tool_to_analyze_data',
              'Q16_Part_1',
         'Q16_Part_2',
         'Q16_Part_3',
         'Q16_Part_4',
         'Q16_Part_5',
         'Q16_Part_6',
         'Q16_Part_7',
         'Q16_Part_8',
         'Q16_Part_9',
         'Q16_Part_10',
         'Q16_Part_11',
         'Q16_Part_12',
         'Q17_Part_1',
         'Q17_Part_2',
         'Q17_Part_3',
         'Q17_Part_4',
         'Q17_Part_5',
         'Q17_Part_6',
         'Q17_Part_7',
         'Q17_Part_8',
         'Q17_Part_9',
         'Q17_Part_10',
         'Q17_Part_11',
         'Q17_Part_12',
         'Q18_Part_1',
         'Q18_Part_2',
         'Q18_Part_3',
         'Q18_Part_4',
         'Q18_Part_5',
         'Q18_Part_6',
         'Q18_Part_7',
         'Q18_Part_8',
         'Q18_Part_9',
         'Q18_Part_10',
         'Q18_Part_11',
         'Q18_Part_12',
         'Q19',
         'Q20_Part_1',
         'Q20_Part_2',
         'Q20_Part_3',
         'Q20_Part_4',
         'Q20_Part_5',
         'Q20_Part_6',
         'Q20_Part_7',
         'Q20_Part_8',
         'Q20_Part_9',
         'Q20_Part_10',
         'Q20_Part_11',
         'Q20_Part_12',
              'Years_ML',
              'Q24_Part_1',
         'Q24_Part_2',
         'Q24_Part_3',
         'Q24_Part_4',
         'Q24_Part_5',
         'Q24_Part_6',
         'Q24_Part_7',
         'Q24_Part_8',
         'Q24_Part_9',
         'Q24_Part_10',
         'Q24_Part_11',
         'Q24_Part_12',
         'Q25_Part_1',
         'Q25_Part_2',
         'Q25_Part_3',
         'Q25_Part_4',
         'Q25_Part_5',
         'Q25_Part_6',
         'Q25_Part_7',
         'Q25_Part_8',
         'Q27_Part_1',
         'Q27_Part_2',
         'Q27_Part_3',
         'Q27_Part_4',
         'Q27_Part_5',
         'Q27_Part_6',
         'Q28_Part_1',
         'Q28_Part_2',
         'Q28_Part_3',
         'Q28_Part_4',
         'Q28_Part_5',
         'Q28_Part_6',
         'Q28_Part_7',
         'Q28_Part_8',
         'Q28_Part_9',
         'Q28_Part_10',
         'Q28_Part_11',
         'Q28_Part_12',
         'Q32_Part_1',
         'Q32_Part_2',
         'Q32_Part_3',
         'Q32_Part_4',
         'Q32_Part_5',
         'Q32_Part_6',
         'Q32_Part_7',
         'Q32_Part_8',
         'Q32_Part_9',
         'Q32_Part_10',
         'Q32_Part_11',
         'Q32_Part_12']
         
              
df
# Out:
#                                age                                  gender  \
# 0      What is your age (# years)?  What is your gender? - Selected Choice
# 1                            22-24                                    Male
# 2                            40-44                                    Male
# 3                            55-59                                  Female
# 4                            40-44                                    Male
# ...                            ...                                     ...
# 19713                        50-54                                    Male
# 19714                        18-21                                    Male
# 19715                        35-39                                    Male
# 19716                        25-29                                    Male
# 19717                        50-54                                    Male
#
#                                          country  \
# ...

# %%
# Combine multiple choice answers
df['Important_Role'] = df[df.columns[12:19]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['Media_sources'] = df[df.columns[23:34]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['Data_Science_Path'] = df[df.columns[36:47]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['IDEs'] = df[df.columns[57:68]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['Notebooks'] = df[df.columns[70:81]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['Languages'] = df[df.columns[83:94]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['Data_visualization_tools'] = df[df.columns[98:109 ]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['ML_alogrithms'] = df[df.columns[119:130]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['ML_tools'] = df[df.columns[132:139]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['NLP_language'] = df[df.columns[149:154]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['ML_frameworks'] = df[df.columns[156:157]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['ML_products'] = df[df.columns[208:219]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

df

# %%
# df.drop(df.loc[:, 'Q9_Part_1':'Q9_Part_7', 'Q12_Part_1':'Q12_Part_12'].columns, axis = 1, inplace = True)
# #df.drop(df.loc[:, 'Q12_Part_1':'Q12_Part_12'].columns, axis = 1, inplace = True)
# df.drop(df.loc[:, 'Q16_Part_1':'Q18_Part_12'].columns, axis = 1, inplace = True)
# df.drop(df.loc[:, 'Q20_Part_1':'Q20_Part_12'].columns, axis = 1, inplace = True)
# df.drop(df.loc[:, 'Q24_Part_1':'Q32_Part_12'].columns, axis = 1, inplace = True)

# %%
Women_df = df[df['gender'] == 'Female']
Women_df

# %%
Men_df = df[df['gender'] == 'Male']
Men_df

# %%
#df.to_csv(r"cleaned_multiple_choice_responses.csv")
