# %%
import pandas as pd

df = pd.read_csv("multiple_choice_responses.csv", index_col=False)
df.head()
# Out:
# C:\Users\snkty\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (0,3,7,19,34,47,49,50,51,52,53,54,68,81,94,96,109,115,130,139,147,154,167,180,193,206,219,232,245) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
# 1                                 510                        22-24
# 2                                 423                        40-44
# 3                                  83                        55-59
# 4                                 391                        40-44
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                    Male
# 2                                    Male
# 3                                  Female
# 4                                    Male
#
#                                        Q2_OTHER_TEXT  \
# 0  What is your gender? - Prefer to self-describe...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# 4                                                 -1
#
#                                           Q3  \
# 0  In which country do you currently reside?
# 1                                     France
# 2                                      India
# 3                                    Germany
# 4                                  Australia
#
#                                                   Q4  \
# 0  What is the highest level of formal education ...
# 1                                    Master’s degree
# 2                                Professional degree
# 3                                Professional degree
# 4                                    Master’s degree
#
#                                                   Q5  \
# 0  Select the title most similar to your current ...
# 1                                  Software Engineer
# 2                                  Software Engineer
# 3                                                NaN
# 4                                              Other
#
#                                        Q5_OTHER_TEXT  \
# 0  Select the title most similar to your current ...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# 4                                                  0
#
#                                                   Q6  \
# 0  What is the size of the company where you are ...
# 1                               1000-9,999 employees
# 2                                 > 10,000 employees
# 3                                                NaN
# 4                                 > 10,000 employees
#
#                                                   Q7  ...  \
# 0  Approximately how many individuals are respons...  ...
# 1                                                  0  ...
# 2                                                20+  ...
# 3                                                NaN  ...
# 4                                                20+  ...
#
#                                           Q34_Part_4  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q34_Part_5  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q34_Part_6  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q34_Part_7  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q34_Part_8  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q34_Part_9  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                 Azure SQL Database
#
#                                          Q34_Part_10  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Q34_Part_11  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Q34_Part_12  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                       Q34_OTHER_TEXT
# 0  Which of the following relational database pro...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# 4                                                 -1
#
# [5 rows x 246 columns]

# %%
# Way too many columns
df = df[['Q1',
         'Q2', 
         'Q3',
         'Q4', 
         'Q5', 
         'Q6',
         'Q7',
         'Q8',
         'Q9_Part_1',
         'Q9_Part_2',
         'Q9_Part_3',
         'Q9_Part_4',
         'Q9_Part_5',
         'Q9_Part_6',
         'Q9_Part_7',
         'Q10',
         'Q11',
         'Q12_Part_1',
         'Q12_Part_2',
         'Q12_Part_3',
         'Q12_Part_4',
         'Q12_Part_5',
         'Q12_Part_6',
         'Q12_Part_7',
         'Q12_Part_8',
         'Q12_Part_9',
         'Q12_Part_10',
         'Q12_Part_11',
         'Q12_Part_12',
         'Q13_Part_1',
         'Q13_Part_2',
         'Q13_Part_3',
         'Q13_Part_4',
         'Q13_Part_5',
         'Q13_Part_6',
         'Q13_Part_7',
         'Q13_Part_8',
         'Q13_Part_9',
         'Q13_Part_10',
         'Q13_Part_11',
         'Q13_Part_12',
         'Q14',
         'Q16_Part_1',
         'Q16_Part_2',
         'Q16_Part_3',
         'Q16_Part_4',
         'Q16_Part_5',
         'Q16_Part_6',
         'Q16_Part_7',
         'Q16_Part_8',
         'Q16_Part_9',
         'Q16_Part_10',
         'Q16_Part_11',
         'Q16_Part_12',
         'Q17_Part_1',
         'Q17_Part_2',
         'Q17_Part_3',
         'Q17_Part_4',
         'Q17_Part_5',
         'Q17_Part_6',
         'Q17_Part_7',
         'Q17_Part_8',
         'Q17_Part_9',
         'Q17_Part_10',
         'Q17_Part_11',
         'Q17_Part_12',
         'Q18_Part_1',
         'Q18_Part_2',
         'Q18_Part_3',
         'Q18_Part_4',
         'Q18_Part_5',
         'Q18_Part_6',
         'Q18_Part_7',
         'Q18_Part_8',
         'Q18_Part_9',
         'Q18_Part_10',
         'Q18_Part_11',
         'Q18_Part_12',
         'Q19',
         'Q20_Part_1',
         'Q20_Part_2',
         'Q20_Part_3',
         'Q20_Part_4',
         'Q20_Part_5',
         'Q20_Part_6',
         'Q20_Part_7',
         'Q20_Part_8',
         'Q20_Part_9',
         'Q20_Part_10',
         'Q20_Part_11',
         'Q20_Part_12',
         'Q23',
         'Q24_Part_1',
         'Q24_Part_2',
         'Q24_Part_3',
         'Q24_Part_4',
         'Q24_Part_5',
         'Q24_Part_6',
         'Q24_Part_7',
         'Q24_Part_8',
         'Q24_Part_9',
         'Q24_Part_10',
         'Q24_Part_11',
         'Q24_Part_12',
         'Q25_Part_1',
         'Q25_Part_2',
         'Q25_Part_3',
         'Q25_Part_4',
         'Q25_Part_5',
         'Q25_Part_6',
         'Q25_Part_7',
         'Q25_Part_8',
         'Q27_Part_1',
         'Q27_Part_2',
         'Q27_Part_3',
         'Q27_Part_4',
         'Q27_Part_5',
         'Q27_Part_6',
         'Q28_Part_1',
         'Q28_Part_2',
         'Q28_Part_3',
         'Q28_Part_4',
         'Q28_Part_5',
         'Q28_Part_6',
         'Q28_Part_7',
         'Q28_Part_8',
         'Q28_Part_9',
         'Q28_Part_10',
         'Q28_Part_11',
         'Q28_Part_12',
         'Q32_Part_1',
         'Q32_Part_2',
         'Q32_Part_3',
         'Q32_Part_4',
         'Q32_Part_5',
         'Q32_Part_6',
         'Q32_Part_7',
         'Q32_Part_8',
         'Q32_Part_9',
         'Q32_Part_10',
         'Q32_Part_11',
         'Q32_Part_12']]

# %%
# Rename Columns 
df.columns = ['age',
              'gender',
              'country',
              'education',
              'job_title',
              'company_size',
              'Number_Ppl_in_Workload',
              'ML_avaliable_at_company',
           'Q9_Part_1',
         'Q9_Part_2',
         'Q9_Part_3',
         'Q9_Part_4',
         'Q9_Part_5',
         'Q9_Part_6',
         'Q9_Part_7',
         'Q9_Part_8',
              'Salary',
              'ML_expenses'
              'Q12_Part_1',
         'Q12_Part_2',
         'Q12_Part_3',
         'Q12_Part_4',
         'Q12_Part_5',
         'Q12_Part_6',
         'Q12_Part_7',
         'Q12_Part_8',
         'Q12_Part_9',
         'Q12_Part_10',
         'Q12_Part_11',
         'Q12_Part_12',
         'Q13_Part_1',
         'Q13_Part_2',
         'Q13_Part_3',
         'Q13_Part_4',
         'Q13_Part_5',
         'Q13_Part_6',
         'Q13_Part_7',
         'Q13_Part_8',
         'Q13_Part_9',
         'Q13_Part_10',
         'Q13_Part_11',
         'Q13_Part_12',
              'Tool_to_analyze_data',
              'Q16_Part_1',
         'Q16_Part_2',
         'Q16_Part_3',
         'Q16_Part_4',
         'Q16_Part_5',
         'Q16_Part_6',
         'Q16_Part_7',
         'Q16_Part_8',
         'Q16_Part_9',
         'Q16_Part_10',
         'Q16_Part_11',
         'Q16_Part_12',
         'Q17_Part_1',
         'Q17_Part_2',
         'Q17_Part_3',
         'Q17_Part_4',
         'Q17_Part_5',
         'Q17_Part_6',
         'Q17_Part_7',
         'Q17_Part_8',
         'Q17_Part_9',
         'Q17_Part_10',
         'Q17_Part_11',
         'Q17_Part_12',
         'Q18_Part_1',
         'Q18_Part_2',
         'Q18_Part_3',
         'Q18_Part_4',
         'Q18_Part_5',
         'Q18_Part_6',
         'Q18_Part_7',
         'Q18_Part_8',
         'Q18_Part_9',
         'Q18_Part_10',
         'Q18_Part_11',
         'Q18_Part_12',
         'Q19',
         'Q20_Part_1',
         'Q20_Part_2',
         'Q20_Part_3',
         'Q20_Part_4',
         'Q20_Part_5',
         'Q20_Part_6',
         'Q20_Part_7',
         'Q20_Part_8',
         'Q20_Part_9',
         'Q20_Part_10',
         'Q20_Part_11',
         'Q20_Part_12',
              'Years_ML',
              'Q24_Part_1',
         'Q24_Part_2',
         'Q24_Part_3',
         'Q24_Part_4',
         'Q24_Part_5',
         'Q24_Part_6',
         'Q24_Part_7',
         'Q24_Part_8',
         'Q24_Part_9',
         'Q24_Part_10',
         'Q24_Part_11',
         'Q24_Part_12',
         'Q25_Part_1',
         'Q25_Part_2',
         'Q25_Part_3',
         'Q25_Part_4',
         'Q25_Part_5',
         'Q25_Part_6',
         'Q25_Part_7',
         'Q25_Part_8',
         'Q27_Part_1',
         'Q27_Part_2',
         'Q27_Part_3',
         'Q27_Part_4',
         'Q27_Part_5',
         'Q27_Part_6',
         'Q28_Part_1',
         'Q28_Part_2',
         'Q28_Part_3',
         'Q28_Part_4',
         'Q28_Part_5',
         'Q28_Part_6',
         'Q28_Part_7',
         'Q28_Part_8',
         'Q28_Part_9',
         'Q28_Part_10',
         'Q28_Part_11',
         'Q28_Part_12',
         'Q32_Part_1',
         'Q32_Part_2',
         'Q32_Part_3',
         'Q32_Part_4',
         'Q32_Part_5',
         'Q32_Part_6',
         'Q32_Part_7',
         'Q32_Part_8',
         'Q32_Part_9',
         'Q32_Part_10',
         'Q32_Part_11',
         'Q32_Part_12']
         
              
df
# Out:
#                                age                                  gender  \
# 0      What is your age (# years)?  What is your gender? - Selected Choice
# 1                            22-24                                    Male
# 2                            40-44                                    Male
# 3                            55-59                                  Female
# 4                            40-44                                    Male
# ...                            ...                                     ...
# 19713                        50-54                                    Male
# 19714                        18-21                                    Male
# 19715                        35-39                                    Male
# 19716                        25-29                                    Male
# 19717                        50-54                                    Male
#
#                                          country  \
# 0      In which country do you currently reside?
# 1                                         France
# 2                                          India
# 3                                        Germany
# 4                                      Australia
# ...                                          ...
# 19713                                      Japan
# 19714                                      India
# 19715                                      India
# 19716                                      India
# 19717                                     France
#
#                                                education  \
# 0      What is the highest level of formal education ...
# 1                                        Master’s degree
# 2                                    Professional degree
# 3                                    Professional degree
# 4                                        Master’s degree
# ...                                                  ...
# 19713                                                NaN
# 19714                                  Bachelor’s degree
# 19715                                    Master’s degree
# 19716                                    Master’s degree
# 19717                                  Bachelor’s degree
#
#                                                job_title  \
# 0      Select the title most similar to your current ...
# 1                                      Software Engineer
# 2                                      Software Engineer
# 3                                                    NaN
# 4                                                  Other
# ...                                                  ...
# 19713                                                NaN
# 19714                                              Other
# 19715                                            Student
# 19716                                       Statistician
# 19717                                  Software Engineer
#
#                                             company_size  \
# 0      What is the size of the company where you are ...
# 1                                   1000-9,999 employees
# 2                                     > 10,000 employees
# 3                                                    NaN
# 4                                     > 10,000 employees
# ...                                                  ...
# 19713                                                NaN
# 19714                                  250-999 employees
# 19715                                                NaN
# 19716                                   50-249 employees
# 19717                                 > 10,000 employees
#
#                                   Number_Ppl_in_Workload  \
# 0      Approximately how many individuals are respons...
# 1                                                      0
# 2                                                    20+
# 3                                                    NaN
# 4                                                    20+
# ...                                                  ...
# 19713                                                NaN
# 19714                                                3-4
# 19715                                                NaN
# 19716                                              15-19
# 19717                                                20+
#
#                                  ML_avaliable_at_company  \
# 0      Does your current employer incorporate machine...
# 1                                          I do not know
# 2      We have well established ML methods (i.e., mod...
# 3                                                    NaN
# 4                                          I do not know
# ...                                                  ...
# 19713                                                NaN
# 19714                                      I do not know
# 19715                                                NaN
# 19716  We recently started using ML methods (i.e., mo...
# 19717  We have well established ML methods (i.e., mod...
#
#                                                Q9_Part_1  \
# 0      Select any activities that make up an importan...
# 1                                                    NaN
# 2      Analyze and understand data to influence produ...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19713                                                NaN
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
#
#                                                Q9_Part_2  ...  \
# 0      Select any activities that make up an importan...  ...
# 1                                                    NaN  ...
# 2      Build and/or run the data infrastructure that ...  ...
# 3                                                    NaN  ...
# 4                                                    NaN  ...
# ...                                                  ...  ...
# 19713                                                NaN  ...
# 19714                                                NaN  ...
# 19715                                                NaN  ...
# 19716                                                NaN  ...
# 19717  Build and/or run the data infrastructure that ...  ...
#
#                                               Q32_Part_3  \
# 0      Which of the following machine learning produc...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                          Azure Machine Learning Studio
# ...                                                  ...
# 19713                                                NaN
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
#
#                                               Q32_Part_4  \
# 0      Which of the following machine learning produc...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19713                                                NaN
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
#
#                                               Q32_Part_5  \
# 0      Which of the following machine learning produc...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19713                                                NaN
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
#
#                                               Q32_Part_6  \
# 0      Which of the following machine learning produc...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19713                                                NaN
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
#
#                                               Q32_Part_7  \
# 0      Which of the following machine learning produc...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19713                                                NaN
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
#
#                                               Q32_Part_8  \
# 0      Which of the following machine learning produc...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19713                                                NaN
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
#
#                                               Q32_Part_9  \
# 0      Which of the following machine learning produc...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19713                                                NaN
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
#
#                                              Q32_Part_10  \
# 0      Which of the following machine learning produc...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19713                                                NaN
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
#
#                                              Q32_Part_11  \
# 0      Which of the following machine learning produc...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19713                                                NaN
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
#
#                                              Q32_Part_12
# 0      Which of the following machine learning produc...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19713                                                NaN
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
#
# [19718 rows x 142 columns]

# %%
# Combine multiple choice answers
df['Important_Role'] = df[df.columns[12:19]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['Media_sources'] = df[df.columns[23:34]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['Data_Science_Path'] = df[df.columns[36:47]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['IDEs'] = df[df.columns[57:68]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['Notebooks'] = df[df.columns[70:81]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['Languages'] = df[df.columns[83:94]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['Data_visualization_tools'] = df[df.columns[98:109 ]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['ML_alogrithms'] = df[df.columns[119:130]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['ML_tools'] = df[df.columns[132:139]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['NLP_language'] = df[df.columns[149:154]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['ML_frameworks'] = df[df.columns[156:157]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['ML_products'] = df[df.columns[208:219]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

df
# Out:
#                                age                                  gender  \
# 0      What is your age (# years)?  What is your gender? - Selected Choice
# 1                            22-24                                    Male
# 2                            40-44                                    Male
# 3                            55-59                                  Female
# 4                            40-44                                    Male
# ...                            ...                                     ...
# 19713                        50-54                                    Male
# 19714                        18-21                                    Male
# 19715                        35-39                                    Male
# 19716                        25-29                                    Male
# 19717                        50-54                                    Male
#
#                                          country  \
# 0      In which country do you currently reside?
# 1                                         France
# 2                                          India
# 3                                        Germany
# 4                                      Australia
# ...                                          ...
# 19713                                      Japan
# 19714                                      India
# 19715                                      India
# 19716                                      India
# 19717                                     France
#
#                                                education  \
# 0      What is the highest level of formal education ...
# 1                                        Master’s degree
# 2                                    Professional degree
# 3                                    Professional degree
# 4                                        Master’s degree
# ...                                                  ...
# 19713                                                NaN
# 19714                                  Bachelor’s degree
# 19715                                    Master’s degree
# 19716                                    Master’s degree
# 19717                                  Bachelor’s degree
#
#                                                job_title  \
# 0      Select the title most similar to your current ...
# 1                                      Software Engineer
# 2                                      Software Engineer
# 3                                                    NaN
# 4                                                  Other
# ...                                                  ...
# 19713                                                NaN
# 19714                                              Other
# 19715                                            Student
# 19716                                       Statistician
# 19717                                  Software Engineer
#
#                                             company_size  \
# 0      What is the size of the company where you are ...
# 1                                   1000-9,999 employees
# 2                                     > 10,000 employees
# 3                                                    NaN
# 4                                     > 10,000 employees
# ...                                                  ...
# 19713                                                NaN
# 19714                                  250-999 employees
# 19715                                                NaN
# 19716                                   50-249 employees
# 19717                                 > 10,000 employees
#
#                                   Number_Ppl_in_Workload  \
# 0      Approximately how many individuals are respons...
# 1                                                      0
# 2                                                    20+
# 3                                                    NaN
# 4                                                    20+
# ...                                                  ...
# 19713                                                NaN
# 19714                                                3-4
# 19715                                                NaN
# 19716                                              15-19
# 19717                                                20+
#
#                                  ML_avaliable_at_company  \
# 0      Does your current employer incorporate machine...
# 1                                          I do not know
# 2      We have well established ML methods (i.e., mod...
# 3                                                    NaN
# 4                                          I do not know
# ...                                                  ...
# 19713                                                NaN
# 19714                                      I do not know
# 19715                                                NaN
# 19716  We recently started using ML methods (i.e., mo...
# 19717  We have well established ML methods (i.e., mod...
#
#                                                Q9_Part_1  \
# 0      Select any activities that make up an importan...
# 1                                                    NaN
# 2      Analyze and understand data to influence produ...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19713                                                NaN
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
#
#                                                Q9_Part_2  ...  \
# 0      Select any activities that make up an importan...  ...
# 1                                                    NaN  ...
# 2      Build and/or run the data infrastructure that ...  ...
# 3                                                    NaN  ...
# 4                                                    NaN  ...
# ...                                                  ...  ...
# 19713                                                NaN  ...
# 19714                                                NaN  ...
# 19715                                                NaN  ...
# 19716                                                NaN  ...
# 19717  Build and/or run the data infrastructure that ...  ...
#
#                                        Data_Science_Path  \
# 0      On which platforms have you begun or completed...
# 1      Udemy;Basic statistical software (Microsoft Ex...
# 2      Udemy;Cloud-based data software & APIs (AWS, G...
# 3
# 4      University Courses (resulting in a university ...
# ...                                                  ...
# 19713
# 19714  Udemy;Local development environments (RStudio,...
# 19715
# 19716
# 19717  Udemy;Local development environments (RStudio,...
#
#                                                     IDEs  \
# 0      Which of the following hosted notebook product...
# 1                                          None;Python;R
# 2
# 3
# 4                                               Python;R
# ...                                                  ...
# 19713
# 19714
# 19715
# 19716
# 19717                          IBM Watson Studio ;Python
#
#                                                Notebooks  \
# 0      What programming languages do you use on a reg...
# 1             Java;Javascript;MATLAB;Python; Matplotlib
# 2
# 3
# 4            Bash;Python; Ggplot / ggplot2 ; Matplotlib
# ...                                                  ...
# 19713
# 19714
# 19715
# 19716
# 19717                      Java;Bash;Python; Matplotlib
#
#                                                Languages  \
# 0      What data visualization libraries or tools do ...
# 1                1-2 years;Linear or Logistic Regression
# 2
# 3
# 4       Seaborn ;2-3 years;Linear or Logistic Regression
# ...                                                  ...
# 19713
# 19714
# 19715
# 19716
# 19717  4-5 years;Linear or Logistic Regression;Decisi...
#
#                                 Data_visualization_tools  \
# 0      Which of the following ML algorithms do you us...
# 1
# 2
# 3
# 4                          Convolutional Neural Networks
# ...                                                  ...
# 19713
# 19714
# 19715
# 19716
# 19717  Automated model selection (e.g. auto-sklearn, ...
#
#                                            ML_alogrithms  \
# 0      Which of the following machine learning framew...
# 1                                                   None
# 2
# 3
# 4                      TensorFlow ; Keras ; RandomForest
# ...                                                  ...
# 19713
# 19714
# 19715
# 19716
# 19717                                        Spark MLib
#
#                                                 ML_tools  \
# 0      Which of the following machine learning produc...
# 1
# 2
# 3
# 4                          Azure Machine Learning Studio
# ...                                                  ...
# 19713
# 19714
# 19715
# 19716
# 19717
#
#                                             NLP_language ML_frameworks  \
# 0      Which of the following machine learning framew...
# 1                                                  None;
# 2                                                      ;
# 3                                                      ;
# 4        TensorFlow ; Keras ; RandomForest;Azure Mach...
# ...                                                  ...           ...
# 19713                                                  ;
# 19714                                                  ;
# 19715                                                  ;
# 19716                                                  ;
# 19717                                       Spark MLib ;
#
#       ML_products
# 0
# 1
# 2
# 3
# 4
# ...           ...
# 19713
# 19714
# 19715
# 19716
# 19717
#
# [19718 rows x 154 columns]

# %%
# df.drop(df.loc[:, 'Q9_Part_1':'Q9_Part_7', 'Q12_Part_1':'Q12_Part_12'].columns, axis = 1, inplace = True)
# #df.drop(df.loc[:, 'Q12_Part_1':'Q12_Part_12'].columns, axis = 1, inplace = True)
# df.drop(df.loc[:, 'Q16_Part_1':'Q18_Part_12'].columns, axis = 1, inplace = True)
# df.drop(df.loc[:, 'Q20_Part_1':'Q20_Part_12'].columns, axis = 1, inplace = True)
# df.drop(df.loc[:, 'Q24_Part_1':'Q32_Part_12'].columns, axis = 1, inplace = True)

# %%
Women_df = df[df['gender'] == 'Female']
Women_df
# Out:
#          age  gender                   country            education  \
# 3      55-59  Female                   Germany  Professional degree
# 8      22-24  Female  United States of America    Bachelor’s degree
# 16     50-54  Female  United States of America      Master’s degree
# 21     22-24  Female                   Ireland      Master’s degree
# 29     30-34  Female                   Ukraine      Doctoral degree
# ...      ...     ...                       ...                  ...
# 19678  30-34  Female                 Australia      Doctoral degree
# 19692  30-34  Female                     India      Master’s degree
# 19695  22-24  Female                     India    Bachelor’s degree
# 19696  25-29  Female                     Japan    Bachelor’s degree
# 19709  25-29  Female                     India  Professional degree
#
#                 job_title          company_size Number_Ppl_in_Workload  \
# 3                     NaN                   NaN                    NaN
# 8          Data Scientist    > 10,000 employees                    20+
# 16           Data Analyst      50-249 employees                    1-2
# 21           Data Analyst  1000-9,999 employees                  10-14
# 29     Research Scientist  1000-9,999 employees                    3-4
# ...                   ...                   ...                    ...
# 19678  Research Scientist  1000-9,999 employees                    20+
# 19692      Data Scientist    > 10,000 employees                  15-19
# 19695   Software Engineer    > 10,000 employees                    1-2
# 19696   Software Engineer                   NaN                    NaN
# 19709        Not employed                   NaN                    NaN
#
#                                  ML_avaliable_at_company  \
# 3                                                    NaN
# 8      We recently started using ML methods (i.e., mo...
# 16     We use ML methods for generating insights (but...
# 21     We are exploring ML methods (and may one day p...
# 29                         No (we do not use ML methods)
# ...                                                  ...
# 19678  We have well established ML methods (i.e., mod...
# 19692  We recently started using ML methods (i.e., mo...
# 19695                      No (we do not use ML methods)
# 19696                                                NaN
# 19709                                                NaN
#
#                                                Q9_Part_1  \
# 3                                                    NaN
# 8      Analyze and understand data to influence produ...
# 16     Analyze and understand data to influence produ...
# 21     Analyze and understand data to influence produ...
# 29                                                   NaN
# ...                                                  ...
# 19678  Analyze and understand data to influence produ...
# 19692                                                NaN
# 19695                                                NaN
# 19696                                                NaN
# 19709                                                NaN
#
#                                                Q9_Part_2  ...  \
# 3                                                    NaN  ...
# 8                                                    NaN  ...
# 16     Build and/or run the data infrastructure that ...  ...
# 21     Build and/or run the data infrastructure that ...  ...
# 29                                                   NaN  ...
# ...                                                  ...  ...
# 19678  Build and/or run the data infrastructure that ...  ...
# 19692                                                NaN  ...
# 19695                                                NaN  ...
# 19696                                                NaN  ...
# 19709                                                NaN  ...
#
#                                        Data_Science_Path  \
# 3
# 8      Udemy;University Courses (resulting in a unive...
# 16     Udemy;Other;Basic statistical software (Micros...
# 21     Udemy;Advanced statistical software (SPSS, SAS...
# 29     Local development environments (RStudio, Jupyt...
# ...                                                  ...
# 19678
# 19692
# 19695
# 19696
# 19709  LinkedIn Learning;University Courses (resultin...
#
#                                                     IDEs  \
# 3
# 8      AWS Notebook Products (EMR Notebooks, Sagemake...
# 16                                         None;Python;R
# 21      Google Cloud Notebook Products (AI Platform, ...
# 29            Binder / JupyterHub ; IBM Watson Studio ;R
# ...                                                  ...
# 19678
# 19692
# 19695
# 19696
# 19709
#
#                                     Notebooks  \
# 3
# 8                         Python; Matplotlib
# 16        SQL; Ggplot / ggplot2 ; Matplotlib
# 21     Python; Ggplot / ggplot2 ; Matplotlib
# 29                       R; Ggplot / ggplot2
# ...                                       ...
# 19678
# 19692
# 19695
# 19696
# 19709
#
#                                                Languages  \
# 3
# 8       Plotly / Plotly Express ;3-4 years;Linear or ...
# 16      Seaborn ;Other;1-2 years;Linear or Logistic R...
# 21      Seaborn ;1-2 years;Linear or Logistic Regress...
# 29               2-3 years;Linear or Logistic Regression
# ...                                                  ...
# 19678
# 19692
# 19695
# 19696
# 19709
#
#                                 Data_visualization_tools  \
# 3
# 8                          Convolutional Neural Networks
# 16
# 21     Automated data augmentation (e.g. imgaug, albu...
# 29
# ...                                                  ...
# 19678
# 19692
# 19695
# 19696
# 19709
#
#                             ML_alogrithms ML_tools  \
# 3
# 8        TensorFlow ; Keras ; Spark MLib
# 16
# 21              TensorFlow ; RandomForest
# 29                                   None
# ...                                   ...      ...
# 19678
# 19692
# 19695
# 19696
# 19709
#
#                               NLP_language ML_frameworks ML_products
# 3                                        ;
# 8        TensorFlow ; Keras ; Spark MLib ;
# 16                                       ;
# 21              TensorFlow ; RandomForest;
# 29                                   None;
# ...                                    ...           ...         ...
# 19678                                    ;
# 19692                                    ;
# 19695                                    ;
# 19696                                    ;
# 19709                                    ;
#
# [3212 rows x 154 columns]

# %%
Men_df = df[df['gender'] == 'Male']
Men_df
# Out:
#          age gender    country            education          job_title  \
# 1      22-24   Male     France      Master’s degree  Software Engineer
# 2      40-44   Male      India  Professional degree  Software Engineer
# 4      40-44   Male  Australia      Master’s degree              Other
# 5      22-24   Male      India    Bachelor’s degree              Other
# 6      50-54   Male     France      Master’s degree     Data Scientist
# ...      ...    ...        ...                  ...                ...
# 19713  50-54   Male      Japan                  NaN                NaN
# 19714  18-21   Male      India    Bachelor’s degree              Other
# 19715  35-39   Male      India      Master’s degree            Student
# 19716  25-29   Male      India      Master’s degree       Statistician
# 19717  50-54   Male     France    Bachelor’s degree  Software Engineer
#
#                company_size Number_Ppl_in_Workload  \
# 1      1000-9,999 employees                      0
# 2        > 10,000 employees                    20+
# 4        > 10,000 employees                    20+
# 5            0-49 employees                      0
# 6            0-49 employees                    3-4
# ...                     ...                    ...
# 19713                   NaN                    NaN
# 19714     250-999 employees                    3-4
# 19715                   NaN                    NaN
# 19716      50-249 employees                  15-19
# 19717    > 10,000 employees                    20+
#
#                                  ML_avaliable_at_company  \
# 1                                          I do not know
# 2      We have well established ML methods (i.e., mod...
# 4                                          I do not know
# 5                          No (we do not use ML methods)
# 6      We have well established ML methods (i.e., mod...
# ...                                                  ...
# 19713                                                NaN
# 19714                                      I do not know
# 19715                                                NaN
# 19716  We recently started using ML methods (i.e., mo...
# 19717  We have well established ML methods (i.e., mod...
#
#                                                Q9_Part_1  \
# 1                                                    NaN
# 2      Analyze and understand data to influence produ...
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# ...                                                  ...
# 19713                                                NaN
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
#
#                                                Q9_Part_2  ...  \
# 1                                                    NaN  ...
# 2      Build and/or run the data infrastructure that ...  ...
# 4                                                    NaN  ...
# 5                                                    NaN  ...
# 6                                                    NaN  ...
# ...                                                  ...  ...
# 19713                                                NaN  ...
# 19714                                                NaN  ...
# 19715                                                NaN  ...
# 19716                                                NaN  ...
# 19717  Build and/or run the data infrastructure that ...  ...
#
#                                        Data_Science_Path  \
# 1      Udemy;Basic statistical software (Microsoft Ex...
# 2      Udemy;Cloud-based data software & APIs (AWS, G...
# 4      University Courses (resulting in a university ...
# 5      Other;Local development environments (RStudio,...
# 6      None;Advanced statistical software (SPSS, SAS,...
# ...                                                  ...
# 19713
# 19714  Udemy;Local development environments (RStudio,...
# 19715
# 19716
# 19717  Udemy;Local development environments (RStudio,...
#
#                                                     IDEs  \
# 1                                          None;Python;R
# 2
# 4                                               Python;R
# 5       Google Cloud Notebook Products (AI Platform, ...
# 6                                          None;Python;R
# ...                                                  ...
# 19713
# 19714
# 19715
# 19716
# 19717                          IBM Watson Studio ;Python
#
#                                          Notebooks  \
# 1       Java;Javascript;MATLAB;Python; Matplotlib
# 2
# 4      Bash;Python; Ggplot / ggplot2 ; Matplotlib
# 5                              Python; Matplotlib
# 6                          Java; Ggplot / ggplot2
# ...                                            ...
# 19713
# 19714
# 19715
# 19716
# 19717                Java;Bash;Python; Matplotlib
#
#                                                Languages  \
# 1                1-2 years;Linear or Logistic Regression
# 2
# 4       Seaborn ;2-3 years;Linear or Logistic Regression
# 5       Plotly / Plotly Express ; Seaborn ;< 1 years;...
# 6      10-15 years;Linear or Logistic Regression;Deci...
# ...                                                  ...
# 19713
# 19714
# 19715
# 19716
# 19717  4-5 years;Linear or Logistic Regression;Decisi...
#
#                                 Data_visualization_tools  \
# 1
# 2
# 4                          Convolutional Neural Networks
# 5
# 6      Convolutional Neural Networks;Generative Adver...
# ...                                                  ...
# 19713
# 19714
# 19715
# 19716
# 19717  Automated model selection (e.g. auto-sklearn, ...
#
#                                            ML_alogrithms  \
# 1                                                   None
# 2
# 4                      TensorFlow ; Keras ; RandomForest
# 5                      RandomForest; Xgboost ; LightGBM
# 6        TensorFlow ; Keras ; RandomForest; Xgboost ;...
# ...                                                  ...
# 19713
# 19714
# 19715
# 19716
# 19717                                        Spark MLib
#
#                             ML_tools  \
# 1
# 2
# 4      Azure Machine Learning Studio
# 5
# 6                         RapidMiner
# ...                              ...
# 19713
# 19714
# 19715
# 19716
# 19717
#
#                                             NLP_language ML_frameworks  \
# 1                                                  None;
# 2                                                      ;
# 4        TensorFlow ; Keras ; RandomForest;Azure Mach...
# 5                     RandomForest; Xgboost ; LightGBM ;
# 6        TensorFlow ; Keras ; RandomForest; Xgboost ;...
# ...                                                  ...           ...
# 19713                                                  ;
# 19714                                                  ;
# 19715                                                  ;
# 19716                                                  ;
# 19717                                       Spark MLib ;
#
#       ML_products
# 1
# 2
# 4
# 5
# 6
# ...           ...
# 19713
# 19714
# 19715
# 19716
# 19717
#
# [16138 rows x 154 columns]

# %%
df.to_csv(r"cleaned_multiple_choice_responses.csv")
