# %%
import pandas as pd

df = pd.read_csv("multiple_choice_responses.csv", index_col=False)
df.head()
# Out:
# C:\Users\snkty\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (0,3,7,19,34,47,49,50,51,52,53,54,68,81,94,96,109,115,130,139,147,154,167,180,193,206,219,232,245) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
# 1                                 510                        22-24
# 2                                 423                        40-44
# 3                                  83                        55-59
# 4                                 391                        40-44
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                    Male
# 2                                    Male
# 3                                  Female
# 4                                    Male
#
#                                        Q2_OTHER_TEXT  \
# 0  What is your gender? - Prefer to self-describe...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# 4                                                 -1
#
#                                           Q3  \
# 0  In which country do you currently reside?
# 1                                     France
# 2                                      India
# 3                                    Germany
# 4                                  Australia
#
#                                                   Q4  \
# 0  What is the highest level of formal education ...
# 1                                    Master’s degree
# 2                                Professional degree
# 3                                Professional degree
# 4                                    Master’s degree
#
#                                                   Q5  \
# 0  Select the title most similar to your current ...
# 1                                  Software Engineer
# 2                                  Software Engineer
# 3                                                NaN
# 4                                              Other
#
#                                        Q5_OTHER_TEXT  \
# 0  Select the title most similar to your current ...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# 4                                                  0
#
#                                                   Q6  \
# 0  What is the size of the company where you are ...
# 1                               1000-9,999 employees
# 2                                 > 10,000 employees
# 3                                                NaN
# 4                                 > 10,000 employees
#
#                                                   Q7  ...  \
# 0  Approximately how many individuals are respons...  ...
# 1                                                  0  ...
# 2                                                20+  ...
# 3                                                NaN  ...
# 4                                                20+  ...
#
#                                           Q34_Part_4  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q34_Part_5  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q34_Part_6  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q34_Part_7  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q34_Part_8  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q34_Part_9  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                 Azure SQL Database
#
#                                          Q34_Part_10  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Q34_Part_11  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Q34_Part_12  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                       Q34_OTHER_TEXT
# 0  Which of the following relational database pro...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# 4                                                 -1
#
# [5 rows x 246 columns]

# %%
# Way too many columns
df = df[['Q1',
         'Q2', 
         'Q3',
         'Q4', 
         'Q5', 
         'Q6',
         'Q7',
         'Q8',
         'Q9_Part_1',
         'Q9_Part_2',
         'Q9_Part_3',
         'Q9_Part_4',
         'Q9_Part_5',
         'Q9_Part_6',
         'Q9_Part_7',
         'Q9_Part_8',
         'Q10',
         'Q11',
         'Q12_Part_1',
         'Q12_Part_2',
         'Q12_Part_3',
         'Q12_Part_4',
         'Q12_Part_5',
         'Q12_Part_6',
         'Q12_Part_7',
         'Q12_Part_8',
         'Q12_Part_9',
         'Q12_Part_10',
         'Q12_Part_11',
         'Q12_Part_12',
         'Q13_Part_1',
         'Q13_Part_2',
         'Q13_Part_3',
         'Q13_Part_4',
         'Q13_Part_5',
         'Q13_Part_6',
         'Q13_Part_7',
         'Q13_Part_8',
         'Q13_Part_9',
         'Q13_Part_10',
         'Q13_Part_11',
         'Q13_Part_12',
         'Q14',
         'Q16_Part_1',
         'Q16_Part_2',
         'Q16_Part_3',
         'Q16_Part_4',
         'Q16_Part_5',
         'Q16_Part_6',
         'Q16_Part_7',
         'Q16_Part_8',
         'Q16_Part_9',
         'Q16_Part_10',
         'Q16_Part_11',
         'Q16_Part_12',
         'Q17_Part_1',
         'Q17_Part_2',
         'Q17_Part_3',
         'Q17_Part_4',
         'Q17_Part_5',
         'Q17_Part_6',
         'Q17_Part_7',
         'Q17_Part_8',
         'Q17_Part_9',
         'Q17_Part_10',
         'Q17_Part_11',
         'Q17_Part_12',
         'Q18_Part_1',
         'Q18_Part_2',
         'Q18_Part_3',
         'Q18_Part_4',
         'Q18_Part_5',
         'Q18_Part_6',
         'Q18_Part_7',
         'Q18_Part_8',
         'Q18_Part_9',
         'Q18_Part_10',
         'Q18_Part_11',
         'Q18_Part_12',
         'Q19',
         'Q20_Part_1',
         'Q20_Part_2',
         'Q20_Part_3',
         'Q20_Part_4',
         'Q20_Part_5',
         'Q20_Part_6',
         'Q20_Part_7',
         'Q20_Part_8',
         'Q20_Part_9',
         'Q20_Part_10',
         'Q20_Part_11',
         'Q20_Part_12',
         'Q23',
         'Q24_Part_1',
         'Q24_Part_2',
         'Q24_Part_3',
         'Q24_Part_4',
         'Q24_Part_5',
         'Q24_Part_6',
         'Q24_Part_7',
         'Q24_Part_8',
         'Q24_Part_9',
         'Q24_Part_10',
         'Q24_Part_11',
         'Q24_Part_12',
         'Q25_Part_1',
         'Q25_Part_2',
         'Q25_Part_3',
         'Q25_Part_4',
         'Q25_Part_5',
         'Q25_Part_6',
         'Q25_Part_7',
         'Q25_Part_8',
         'Q27_Part_1',
         'Q27_Part_2',
         'Q27_Part_3',
         'Q27_Part_4',
         'Q27_Part_5',
         'Q27_Part_6',
         'Q28_Part_1',
         'Q28_Part_2',
         'Q28_Part_3',
         'Q28_Part_4',
         'Q28_Part_5',
         'Q28_Part_6',
         'Q28_Part_7',
         'Q28_Part_8',
         'Q28_Part_9',
         'Q28_Part_10',
         'Q28_Part_11',
         'Q28_Part_12',
         'Q32_Part_1',
         'Q32_Part_2',
         'Q32_Part_3',
         'Q32_Part_4',
         'Q32_Part_5',
         'Q32_Part_6',
         'Q32_Part_7',
         'Q32_Part_8',
         'Q32_Part_9',
         'Q32_Part_10',
         'Q32_Part_11',
         'Q32_Part_12']]

# %%
# Rename Columns 
df.columns = ['Age',
         'Gender', 
         'Country',
         'Education', 
         'Job_Title', 
         'Company_Size',
         'Work_Load_Size',
         'Does_Compnay_Used_ML',
         'Q9_Part_1',
         'Q9_Part_2',
         'Q9_Part_3',
         'Q9_Part_4',
         'Q9_Part_5',
         'Q9_Part_6',
         'Q9_Part_7',
         'Q9_Part_8',
         'Salary',
         'Money_Spent_On_ML',
         'Q12_Part_1',
         'Q12_Part_2',
         'Q12_Part_3',
         'Q12_Part_4',
         'Q12_Part_5',
         'Q12_Part_6',
         'Q12_Part_7',
         'Q12_Part_8',
         'Q12_Part_9',
         'Q12_Part_10',
         'Q12_Part_11',
         'Q12_Part_12',
         'Q13_Part_1',
         'Q13_Part_2',
         'Q13_Part_3',
         'Q13_Part_4',
         'Q13_Part_5',
         'Q13_Part_6',
         'Q13_Part_7',
         'Q13_Part_8',
         'Q13_Part_9',
         'Q13_Part_10',
         'Q13_Part_11',
         'Q13_Part_12',
         'Primary_Analysis_Tool',
         'Q16_Part_1',
         'Q16_Part_2',
         'Q16_Part_3',
         'Q16_Part_4',
         'Q16_Part_5',
         'Q16_Part_6',
         'Q16_Part_7',
         'Q16_Part_8',
         'Q16_Part_9',
         'Q16_Part_10',
         'Q16_Part_11',
         'Q16_Part_12',
         'Q17_Part_1',
         'Q17_Part_2',
         'Q17_Part_3',
         'Q17_Part_4',
         'Q17_Part_5',
         'Q17_Part_6',
         'Q17_Part_7',
         'Q17_Part_8',
         'Q17_Part_9',
         'Q17_Part_10',
         'Q17_Part_11',
         'Q17_Part_12',
         'Q18_Part_1',
         'Q18_Part_2',
         'Q18_Part_3',
         'Q18_Part_4',
         'Q18_Part_5',
         'Q18_Part_6',
         'Q18_Part_7',
         'Q18_Part_8',
         'Q18_Part_9',
         'Q18_Part_10',
         'Q18_Part_11',
         'Q18_Part_12',
         'Programming_Language_For_First_Time_Users',
         'Q20_Part_1',
         'Q20_Part_2',
         'Q20_Part_3',
         'Q20_Part_4',
         'Q20_Part_5',
         'Q20_Part_6',
         'Q20_Part_7',
         'Q20_Part_8',
         'Q20_Part_9',
         'Q20_Part_10',
         'Q20_Part_11',
         'Q20_Part_12',
         'Years_Using_ML',
         'Q24_Part_1',
         'Q24_Part_2',
         'Q24_Part_3',
         'Q24_Part_4',
         'Q24_Part_5',
         'Q24_Part_6',
         'Q24_Part_7',
         'Q24_Part_8',
         'Q24_Part_9',
         'Q24_Part_10',
         'Q24_Part_11',
         'Q24_Part_12',
         'Q25_Part_1',
         'Q25_Part_2',
         'Q25_Part_3',
         'Q25_Part_4',
         'Q25_Part_5',
         'Q25_Part_6',
         'Q25_Part_7',
         'Q25_Part_8',
         'Q27_Part_1',
         'Q27_Part_2',
         'Q27_Part_3',
         'Q27_Part_4',
         'Q27_Part_5',
         'Q27_Part_6',
         'Q28_Part_1',
         'Q28_Part_2',
         'Q28_Part_3',
         'Q28_Part_4',
         'Q28_Part_5',
         'Q28_Part_6',
         'Q28_Part_7',
         'Q28_Part_8',
         'Q28_Part_9',
         'Q28_Part_10',
         'Q28_Part_11',
         'Q28_Part_12',
         'Q32_Part_1',
         'Q32_Part_2',
         'Q32_Part_3',
         'Q32_Part_4',
         'Q32_Part_5',
         'Q32_Part_6',
         'Q32_Part_7',
         'Q32_Part_8',
         'Q32_Part_9',
         'Q32_Part_10',
         'Q32_Part_11',
         'Q32_Part_12']

              
df.fillna(0)
# Out:
#                                Age                                  Gender  \
# 0      What is your age (# years)?  What is your gender? - Selected Choice
# 1                            22-24                                    Male
# 2                            40-44                                    Male
# 3                            55-59                                  Female
# 4                            40-44                                    Male
# ...                            ...                                     ...
# 19713                        50-54                                    Male
# 19714                        18-21                                    Male
# 19715                        35-39                                    Male
# 19716                        25-29                                    Male
# 19717                        50-54                                    Male
#
#                                          Country  \
# 0      In which country do you currently reside?
# 1                                         France
# 2                                          India
# 3                                        Germany
# 4                                      Australia
# ...                                          ...
# 19713                                      Japan
# 19714                                      India
# 19715                                      India
# 19716                                      India
# 19717                                     France
#
#                                                Education  \
# 0      What is the highest level of formal education ...
# 1                                        Master’s degree
# 2                                    Professional degree
# 3                                    Professional degree
# 4                                        Master’s degree
# ...                                                  ...
# 19713                                                  0
# 19714                                  Bachelor’s degree
# 19715                                    Master’s degree
# 19716                                    Master’s degree
# 19717                                  Bachelor’s degree
#
#                                                Job_Title  \
# 0      Select the title most similar to your current ...
# 1                                      Software Engineer
# 2                                      Software Engineer
# 3                                                      0
# 4                                                  Other
# ...                                                  ...
# 19713                                                  0
# 19714                                              Other
# 19715                                            Student
# 19716                                       Statistician
# 19717                                  Software Engineer
#
#                                             Company_Size  \
# 0      What is the size of the company where you are ...
# 1                                   1000-9,999 employees
# 2                                     > 10,000 employees
# 3                                                      0
# 4                                     > 10,000 employees
# ...                                                  ...
# 19713                                                  0
# 19714                                  250-999 employees
# 19715                                                  0
# 19716                                   50-249 employees
# 19717                                 > 10,000 employees
#
#                                           Work_Load_Size  \
# 0      Approximately how many individuals are respons...
# 1                                                      0
# 2                                                    20+
# 3                                                      0
# 4                                                    20+
# ...                                                  ...
# 19713                                                  0
# 19714                                                3-4
# 19715                                                  0
# 19716                                              15-19
# 19717                                                20+
#
#                                     Does_Compnay_Used_ML  \
# 0      Does your current employer incorporate machine...
# 1                                          I do not know
# 2      We have well established ML methods (i.e., mod...
# 3                                                      0
# 4                                          I do not know
# ...                                                  ...
# 19713                                                  0
# 19714                                      I do not know
# 19715                                                  0
# 19716  We recently started using ML methods (i.e., mo...
# 19717  We have well established ML methods (i.e., mod...
#
#                                                Q9_Part_1  \
# 0      Select any activities that make up an importan...
# 1                                                      0
# 2      Analyze and understand data to influence produ...
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 19713                                                  0
# 19714                                                  0
# 19715                                                  0
# 19716                                                  0
# 19717                                                  0
#
#                                                Q9_Part_2  ...  \
# 0      Select any activities that make up an importan...  ...
# 1                                                      0  ...
# 2      Build and/or run the data infrastructure that ...  ...
# 3                                                      0  ...
# 4                                                      0  ...
# ...                                                  ...  ...
# 19713                                                  0  ...
# 19714                                                  0  ...
# 19715                                                  0  ...
# 19716                                                  0  ...
# 19717  Build and/or run the data infrastructure that ...  ...
#
#                                               Q32_Part_3  \
# 0      Which of the following machine learning produc...
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                          Azure Machine Learning Studio
# ...                                                  ...
# 19713                                                  0
# 19714                                                  0
# 19715                                                  0
# 19716                                                  0
# 19717                                                  0
#
#                                               Q32_Part_4  \
# 0      Which of the following machine learning produc...
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 19713                                                  0
# 19714                                                  0
# 19715                                                  0
# 19716                                                  0
# 19717                                                  0
#
#                                               Q32_Part_5  \
# 0      Which of the following machine learning produc...
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 19713                                                  0
# 19714                                                  0
# 19715                                                  0
# 19716                                                  0
# 19717                                                  0
#
#                                               Q32_Part_6  \
# 0      Which of the following machine learning produc...
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 19713                                                  0
# 19714                                                  0
# 19715                                                  0
# 19716                                                  0
# 19717                                                  0
#
#                                               Q32_Part_7  \
# 0      Which of the following machine learning produc...
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 19713                                                  0
# 19714                                                  0
# 19715                                                  0
# 19716                                                  0
# 19717                                                  0
#
#                                               Q32_Part_8  \
# 0      Which of the following machine learning produc...
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 19713                                                  0
# 19714                                                  0
# 19715                                                  0
# 19716                                                  0
# 19717                                                  0
#
#                                               Q32_Part_9  \
# 0      Which of the following machine learning produc...
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 19713                                                  0
# 19714                                                  0
# 19715                                                  0
# 19716                                                  0
# 19717                                                  0
#
#                                              Q32_Part_10  \
# 0      Which of the following machine learning produc...
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 19713                                                  0
# 19714                                                  0
# 19715                                                  0
# 19716                                                  0
# 19717                                                  0
#
#                                              Q32_Part_11  \
# 0      Which of the following machine learning produc...
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 19713                                                  0
# 19714                                                  0
# 19715                                                  0
# 19716                                                  0
# 19717                                                  0
#
#                                              Q32_Part_12
# 0      Which of the following machine learning produc...
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 19713                                                  0
# 19714                                                  0
# 19715                                                  0
# 19716                                                  0
# 19717                                                  0
#
# [19718 rows x 143 columns]

# %%
#Combine Multiple Choice Answers in Each Column


df['Important_Role'] = df[['Q9_Part_1',
                           'Q9_Part_2',
                           'Q9_Part_3',
                           'Q9_Part_4',
                           'Q9_Part_5',
                           'Q9_Part_6',
                           'Q9_Part_7',
                           'Q9_Part_8']].apply(
    lambda x: ','.join(x.astype(str).replace(['nan', 'None'], '')), axis = 1)







df['Data_Science_Path'] = df[['Q13_Part_1',
                              'Q13_Part_2',
                              'Q13_Part_3',
                              'Q13_Part_4',
                              'Q13_Part_5',
                              'Q13_Part_6',
                              'Q13_Part_7',
                              'Q13_Part_8',
                              'Q13_Part_9',
                              'Q13_Part_10',
                              'Q13_Part_11',
                              'Q13_Part_12']].apply(
    lambda x: ','.join(x.astype(str).replace(['nan', 'None'], '')), axis = 1)



df['IDEs'] = df[['Q16_Part_1',
                 'Q16_Part_2',
                 'Q16_Part_3',
                 'Q16_Part_4',
                 'Q16_Part_5',
                 'Q16_Part_6',
                 'Q16_Part_7',
                 'Q16_Part_8',
                 'Q16_Part_9',
                 'Q16_Part_10',
                 'Q16_Part_11',
                 'Q16_Part_12']].apply(
    lambda x: ','.join(x.astype(str).replace(['nan', 'None'], '')), axis = 1)


df['Notebooks'] = df[['Q17_Part_1',
                      'Q17_Part_2',
                      'Q17_Part_3',
                      'Q17_Part_4',
                      'Q17_Part_5',
                      'Q17_Part_6',
                      'Q17_Part_7',
                      'Q17_Part_8',
                      'Q17_Part_9',
                      'Q17_Part_10',
                      'Q17_Part_11',
                      'Q17_Part_12']].apply(
    lambda x: ','.join(x.astype(str).replace(['nan', 'None'], '')), axis = 1)



df['Programmng_Languages_Used'] = df[['Q18_Part_1',
                                      'Q18_Part_2',
                                      'Q18_Part_3',
                                      'Q18_Part_4',
                                      'Q18_Part_5',
                                      'Q18_Part_6',
                                      'Q18_Part_7',
                                      'Q18_Part_8',
                                      'Q18_Part_9',
                                      'Q18_Part_10',
                                      'Q18_Part_11',
                                      'Q18_Part_12']].apply(
    lambda x: ','.join(x.astype(str).replace(['nan', 'None'], '')), axis = 1)


df['Data_Visualization_Tools'] = df[['Q20_Part_1',
                                     'Q20_Part_2',
                                     'Q20_Part_3',
                                     'Q20_Part_4',
                                     'Q20_Part_5',
                                     'Q20_Part_6',
                                     'Q20_Part_7',
                                     'Q20_Part_8',
                                     'Q20_Part_9',
                                     'Q20_Part_10',
                                     'Q20_Part_11',
                                     'Q20_Part_12']].apply(
    lambda x: ','.join(x.astype(str).replace(['nan', 'None'], '')), axis = 1)


df['ML_Alogrithms'] = df[['Q24_Part_1',
                          'Q24_Part_2',
                          'Q24_Part_3',
                          'Q24_Part_4',
                          'Q24_Part_5',
                          'Q24_Part_6',
                          'Q24_Part_7',
                          'Q24_Part_8',
                          'Q24_Part_9',
                          'Q24_Part_10',
                          'Q24_Part_11',
                          'Q24_Part_12']].apply(
    lambda x: ','.join(x.astype(str).replace(['nan', 'None'], '')), axis = 1)


df['ML_Tools'] = df[['Q25_Part_1',
                     'Q25_Part_2',
                     'Q25_Part_3',
                     'Q25_Part_4',
                     'Q25_Part_5',
                     'Q25_Part_6',
                     'Q25_Part_7',
                     'Q25_Part_8',]].apply(
    lambda x: ','.join(x.astype(str).replace(['nan', 'None'], '')), axis = 1)


df['NLP_Language'] = df[['Q27_Part_1',
                         'Q27_Part_2',
                         'Q27_Part_3',
                         'Q27_Part_4',
                         'Q27_Part_5',
                         'Q27_Part_6',]].apply(
    lambda x: ','.join(x.astype(str).replace(['nan', 'None'], '')), axis = 1)





df['ML_Frameworks'] = df[['Q28_Part_1',
                        'Q28_Part_2',
                        'Q28_Part_3',
                        'Q28_Part_4',
                        'Q28_Part_5',
                        'Q28_Part_6',
                        'Q28_Part_7',
                        'Q28_Part_8',
                        'Q28_Part_9',
                        'Q28_Part_10',
                        'Q28_Part_11',
                        'Q28_Part_12']].apply(
    lambda x: ','.join(x.astype(str).replace(['nan', 'None'], '')), axis = 1)



df['ML_Products'] = df[['Q32_Part_1',
                        'Q32_Part_2',
                        'Q32_Part_3',
                        'Q32_Part_4',
                        'Q32_Part_5',
                        'Q32_Part_6',
                        'Q32_Part_7',
                        'Q32_Part_8',
                        'Q32_Part_9',
                        'Q32_Part_10',
                        'Q32_Part_11',
                        'Q32_Part_12']].apply(
    lambda x: ','.join(x.astype(str).replace(['nan', 'None'], '')), axis = 1)

# %%
# Remove Individual Answer Columns
for col in df.columns:
    if 'Part_' in col:
        del df[col]

# %%
# Remove NAN Values
df = df.dropna()

# %%
Women_df = df[df['Gender'] == 'Female']
Women_df
# Out:
#          Age  Gender                   Country          Education  \
# 8      22-24  Female  United States of America  Bachelor’s degree
# 16     50-54  Female  United States of America    Master’s degree
# 21     22-24  Female                   Ireland    Master’s degree
# 29     30-34  Female                   Ukraine    Doctoral degree
# 30     25-29  Female                  Pakistan    Master’s degree
# ...      ...     ...                       ...                ...
# 19074  30-34  Female                     China    Master’s degree
# 19081  22-24  Female                     India    Master’s degree
# 19124  35-39  Female                    Brazil    Master’s degree
# 19465  25-29  Female                     Kenya    Master’s degree
# 19583  22-24  Female                     Other  Bachelor’s degree
#
#                 Job_Title          Company_Size Work_Load_Size  \
# 8          Data Scientist    > 10,000 employees            20+
# 16           Data Analyst      50-249 employees            1-2
# 21           Data Analyst  1000-9,999 employees          10-14
# 29     Research Scientist  1000-9,999 employees            3-4
# 30     Research Scientist        0-49 employees          10-14
# ...                   ...                   ...            ...
# 19074      Data Scientist      50-249 employees            5-9
# 19081        Data Analyst    > 10,000 employees            5-9
# 19124               Other      50-249 employees              0
# 19465        Data Analyst    > 10,000 employees            1-2
# 19583               Other      50-249 employees            1-2
#
#                                     Does_Compnay_Used_ML           Salary  \
# 8      We recently started using ML methods (i.e., mo...    80,000-89,999
# 16     We use ML methods for generating insights (but...  125,000-149,999
# 21     We are exploring ML methods (and may one day p...    20,000-24,999
# 29                         No (we do not use ML methods)           $0-999
# 30     We use ML methods for generating insights (but...           $0-999
# ...                                                  ...              ...
# 19074  We recently started using ML methods (i.e., mo...      1,000-1,999
# 19081  We recently started using ML methods (i.e., mo...      5,000-7,499
# 19124  We use ML methods for generating insights (but...  100,000-124,999
# 19465                      No (we do not use ML methods)      3,000-3,999
# 19583  We are exploring ML methods (and may one day p...      5,000-7,499
#
#        Money_Spent_On_ML  ...  \
# 8               $0 (USD)  ...
# 16     > $100,000 ($USD)  ...
# 21     > $100,000 ($USD)  ...
# 29                $1-$99  ...
# 30              $0 (USD)  ...
# ...                  ...  ...
# 19074       $1000-$9,999  ...
# 19081           $0 (USD)  ...
# 19124          $100-$999  ...
# 19465           $0 (USD)  ...
# 19583          $100-$999  ...
#
#                                        Data_Science_Path  \
# 8      ,,,,,,,Udemy,,University Courses (resulting in...
# 16                      ,Coursera,edX,,,,,Udemy,,,,Other
# 21     ,,,DataCamp,,Kaggle Courses (i.e. Kaggle Learn...
# 29                                   ,Coursera,,,,,,,,,,
# 30     ,Coursera,edX,DataCamp,,Kaggle Courses (i.e. K...
# ...                                                  ...
# 19074                         Udacity,Coursera,,,,,,,,,,
# 19081  ,Coursera,,,,,,,,University Courses (resulting...
# 19124  Udacity,Coursera,,DataCamp,DataQuest,Kaggle Co...
# 19465   ,,edX,,,Kaggle Courses (i.e. Kaggle Learn),,,,,,
# 19583  Udacity,Coursera,edX,,,Kaggle Courses (i.e. Ka...
#
#                                                     IDEs  \
# 8      Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# 16     Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# 21     Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# 29                                  , RStudio ,,,,,,,,,,
# 30     Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# ...                                                  ...
# 19074  Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# 19081  Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# 19124  Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# 19465  Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# 19583  Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
#
#                                                Notebooks  \
# 8      ,, Microsoft Azure Notebooks ,,,,,,,AWS Notebo...
# 16                                           ,,,,,,,,,,,
# 21     , Google Colab ,, Google Cloud Notebook Produc...
# 29     ,,,,,, Binder / JupyterHub , IBM Watson Studio...
# 30                                           ,,,,,,,,,,,
# ...                                                  ...
# 19074                   ,,,,,, Binder / JupyterHub ,,,,,
# 19081             Kaggle Notebooks (Kernels) ,,,,,,,,,,,
# 19124             Kaggle Notebooks (Kernels) ,,,,,,,,,,,
# 19465   Kaggle Notebooks (Kernels) ,,,,,, Binder / Ju...
# 19583                          , Google Colab ,,,,,,,,,,
#
#       Programmng_Languages_Used  \
# 8             Python,,,,,,,,,,,
# 16        Python,R,SQL,,,,,,,,,
# 21         Python,,SQL,,,,,,,,,
# 29                 ,R,,,,,,,,,,
# 30            Python,,,,,,,,,,,
# ...                         ...
# 19074      Python,,SQL,,,,,,,,,
# 19081        Python,R,,,,,,,,,,
# 19124         Python,,,,,,,,,,,
# 19465      Python,,SQL,,,,,,,,,
# 19583         Python,,,,,,,,,,,
#
#                                 Data_Visualization_Tools  \
# 8       , Matplotlib ,,,, Plotly / Plotly Express ,,,,,,
# 16      Ggplot / ggplot2 , Matplotlib ,,,,,, Seaborn ...
# 21      Ggplot / ggplot2 , Matplotlib ,,,,,, Seaborn ...
# 29                          Ggplot / ggplot2 ,,,,,,,,,,,
# 30                               , Matplotlib ,,,,,,,,,,
# ...                                                  ...
# 19074               ,,,,, Plotly / Plotly Express ,,,,,,
# 19081  , Matplotlib ,,,, Plotly / Plotly Express ,, S...
# 19124                   , Matplotlib ,,,,,, Seaborn ,,,,
# 19465   Ggplot / ggplot2 , Matplotlib ,,,,,, Seaborn ...
# 19583                   , Matplotlib ,,,,,, Seaborn ,,,,
#
#                                            ML_Alogrithms  \
# 8      Linear or Logistic Regression,Decision Trees o...
# 16     Linear or Logistic Regression,Decision Trees o...
# 21     Linear or Logistic Regression,Decision Trees o...
# 29              Linear or Logistic Regression,,,,,,,,,,,
# 30                                           ,,,,,,,,,,,
# ...                                                  ...
# 19074  Linear or Logistic Regression,Decision Trees o...
# 19081  Linear or Logistic Regression,Decision Trees o...
# 19124  Linear or Logistic Regression,Decision Trees o...
# 19465                                        ,,,,,,,,,,,
# 19583  Linear or Logistic Regression,Decision Trees o...
#
#                                                 ML_Tools NLP_Language  \
# 8                                                ,,,,,,,        ,,,,,
# 16                                               ,,,,,,,        ,,,,,
# 21     Automated data augmentation (e.g. imgaug, albu...        ,,,,,
# 29                                               ,,,,,,,        ,,,,,
# 30     ,,Automated model selection (e.g. auto-sklearn...        ,,,,,
# ...                                                  ...          ...
# 19074  ,Automated feature engineering/selection (e.g....        ,,,,,
# 19081                                            ,,,,,,,        ,,,,,
# 19124                                            ,,,,,,,        ,,,,,
# 19465                                            ,,,,,,,        ,,,,,
# 19583  ,,,,Automated hyperparameter tuning (e.g. hype...        ,,,,,
#
#                                            ML_Frameworks  \
# 8        Scikit-learn ,  TensorFlow , Keras ,,,,,, Sp...
# 16                              Scikit-learn ,,,,,,,,,,,
# 21       Scikit-learn ,  TensorFlow ,, RandomForest,,...
# 29                                           ,,,,,,,,,,,
# 30                              Scikit-learn ,,,,,,,,,,,
# ...                                                  ...
# 19074    Scikit-learn ,,, RandomForest, Xgboost ,, Ca...
# 19081              Scikit-learn ,,, RandomForest,,,,,,,,
# 19124                           Scikit-learn ,,,,,,,,,,,
# 19465                                        ,,,,,,,,,,,
# 19583     Scikit-learn ,  TensorFlow ,,,, PyTorch ,,,,,,
#
#                                     ML_Products
# 8                                   ,,,,,,,,,,,
# 16                                  ,,,,,,,,,,,
# 21                                  ,,,,,,,,,,,
# 29                                  ,,,,,,,,,,,
# 30                                  ,,,,,,,,,,,
# ...                                         ...
# 19074  ,,,,,,Google Cloud Natural Language,,,,,
# 19081                               ,,,,,,,,,,,
# 19124                               ,,,,,,,,,,,
# 19465                               ,,,,,,,,,,,
# 19583                          ,,,,,,,,,,,Other
#
# [1453 rows x 24 columns]

# %%
Men_df = df[df['Gender'] == 'Male']
Men_df
# Out:
#          Age Gender    Country               Education           Job_Title  \
# 1      22-24   Male     France         Master’s degree   Software Engineer
# 4      40-44   Male  Australia         Master’s degree               Other
# 5      22-24   Male      India       Bachelor’s degree               Other
# 6      50-54   Male     France         Master’s degree      Data Scientist
# 7      22-24   Male      India         Master’s degree      Data Scientist
# ...      ...    ...        ...                     ...                 ...
# 19570  22-24   Male  Indonesia         Master’s degree  Research Scientist
# 19604  22-24   Male     Sweden         Master’s degree        Statistician
# 19664  25-29   Male      China  I prefer not to answer       Data Engineer
# 19691  25-29   Male  Australia       Bachelor’s degree               Other
# 19717  50-54   Male     France       Bachelor’s degree   Software Engineer
#
#                Company_Size Work_Load_Size  \
# 1      1000-9,999 employees              0
# 4        > 10,000 employees            20+
# 5            0-49 employees              0
# 6            0-49 employees            3-4
# 7          50-249 employees            20+
# ...                     ...            ...
# 19570        0-49 employees            3-4
# 19604  1000-9,999 employees            5-9
# 19664     250-999 employees            5-9
# 19691  1000-9,999 employees            5-9
# 19717    > 10,000 employees            20+
#
#                                     Does_Compnay_Used_ML           Salary  \
# 1                                          I do not know    30,000-39,999
# 4                                          I do not know  250,000-299,999
# 5                          No (we do not use ML methods)      4,000-4,999
# 6      We have well established ML methods (i.e., mod...    60,000-69,999
# 7      We are exploring ML methods (and may one day p...    10,000-14,999
# ...                                                  ...              ...
# 19570  We use ML methods for generating insights (but...           $0-999
# 19604                      No (we do not use ML methods)    30,000-39,999
# 19664  We recently started using ML methods (i.e., mo...    20,000-24,999
# 19691                      No (we do not use ML methods)    60,000-69,999
# 19717  We have well established ML methods (i.e., mod...    60,000-69,999
#
#       Money_Spent_On_ML  ...  \
# 1              $0 (USD)  ...
# 4       $10,000-$99,999  ...
# 5              $0 (USD)  ...
# 6       $10,000-$99,999  ...
# 7             $100-$999  ...
# ...                 ...  ...
# 19570         $100-$999  ...
# 19604          $0 (USD)  ...
# 19664         $100-$999  ...
# 19691   $10,000-$99,999  ...
# 19717          $0 (USD)  ...
#
#                                        Data_Science_Path  \
# 1      ,Coursera,,DataCamp,,Kaggle Courses (i.e. Kagg...
# 4      ,Coursera,edX,DataCamp,,,,,,University Courses...
# 5                                       ,,,,,,,,,,,Other
# 6                                            ,,,,,,,,,,,
# 7      Udacity,Coursera,edX,,,Kaggle Courses (i.e. Ka...
# ...                                                  ...
# 19570  Udacity,,,,,,,,,University Courses (resulting ...
# 19604                                ,Coursera,,,,,,,,,,
# 19664      ,,,,,Kaggle Courses (i.e. Kaggle Learn),,,,,,
# 19691                 ,Coursera,edX,,,,Fast.ai,Udemy,,,,
# 19717                        ,Coursera,edX,,,,,Udemy,,,,
#
#                                                     IDEs  \
# 1      Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# 4      Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# 5      Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# 6                              , RStudio ,,,,,,,,,,Other
# 7      Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# ...                                                  ...
# 19570  Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# 19604  Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# 19664  Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# 19691  Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# 19717  Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
#
#                                                Notebooks  \
# 1                                            ,,,,,,,,,,,
# 4                 ,, Microsoft Azure Notebooks ,,,,,,,,,
# 5      , Google Colab ,, Google Cloud Notebook Produc...
# 6                                            ,,,,,,,,,,,
# 7       Kaggle Notebooks (Kernels) , Google Colab ,,,...
# ...                                                  ...
# 19570   Kaggle Notebooks (Kernels) , Google Colab ,,,...
# 19604                                        ,,,,,,,,,,,
# 19664                          , Google Colab ,,,,,,,,,,
# 19691                                        ,,,,,,,,,,,
# 19717                     ,,,,,,, IBM Watson Studio ,,,,
#
#                        Programmng_Languages_Used  \
# 1      Python,R,SQL,,,Java,Javascript,,,MATLAB,,
# 4                      Python,R,SQL,,,,,,Bash,,,
# 5                           Python,,SQL,,,,,,,,,
# 6                             Python,R,,,,,,,,,,
# 7                         Python,R,,,,,,,Bash,,,
# ...                                          ...
# 19570               Python,R,,,,,Javascript,,,,,
# 19604                   Python,R,,,,,,,,MATLAB,,
# 19664                          Python,,,,,,,,,,,
# 19691                 Python,,SQL,,,,,,,MATLAB,,
# 19717               Python,,SQL,,,Java,,,Bash,,,
#
#                                 Data_Visualization_Tools  \
# 1                                , Matplotlib ,,,,,,,,,,
# 4       Ggplot / ggplot2 , Matplotlib ,,,,,, Seaborn ...
# 5      , Matplotlib ,,,, Plotly / Plotly Express ,, S...
# 6                           Ggplot / ggplot2 ,,,,,,,,,,,
# 7      , Matplotlib ,,,, Plotly / Plotly Express , Bo...
# ...                                                  ...
# 19570   Ggplot / ggplot2 , Matplotlib ,, Shiny , D3.j...
# 19604   Ggplot / ggplot2 , Matplotlib ,,,, Plotly / P...
# 19664                               ,,,,,,, Seaborn ,,,,
# 19691  , Matplotlib ,,,, Plotly / Plotly Express , Bo...
# 19717                            , Matplotlib ,,,,,,,,,,
#
#                                            ML_Alogrithms  \
# 1               Linear or Logistic Regression,,,,,,,,,,,
# 4      Linear or Logistic Regression,,,,,,Convolution...
# 5      Linear or Logistic Regression,Decision Trees o...
# 6      Linear or Logistic Regression,Decision Trees o...
# 7      Linear or Logistic Regression,,,,,Dense Neural...
# ...                                                  ...
# 19570  Linear or Logistic Regression,Decision Trees o...
# 19604  Linear or Logistic Regression,Decision Trees o...
# 19664  ,,,,,Dense Neural Networks (MLPs, etc),,,Recur...
# 19691  Linear or Logistic Regression,Decision Trees o...
# 19717  Linear or Logistic Regression,Decision Trees o...
#
#                                                 ML_Tools  \
# 1                                                ,,,,,,,
# 4      ,,,,,Automation of full ML pipelines (e.g. Goo...
# 5                                                ,,,,,,,
# 6      ,,Automated model selection (e.g. auto-sklearn...
# 7      Automated data augmentation (e.g. imgaug, albu...
# ...                                                  ...
# 19570  Automated data augmentation (e.g. imgaug, albu...
# 19604                                            ,,,,,,,
# 19664                                            ,,,,,,,
# 19691                                            ,,,,,,,
# 19717  ,,Automated model selection (e.g. auto-sklearn...
#
#                                             NLP_Language  \
# 1                                                  ,,,,,
# 4                                                  ,,,,,
# 5                                                  ,,,,,
# 6      Word embeddings/vectors (GLoVe, fastText, word...
# 7      Word embeddings/vectors (GLoVe, fastText, word...
# ...                                                  ...
# 19570                                              ,,,,,
# 19604                                              ,,,,,
# 19664  Word embeddings/vectors (GLoVe, fastText, word...
# 19691                                              ,,,,,
# 19717                                              ,,,,,
#
#                                            ML_Frameworks  \
# 1                                            ,,,,,,,,,,,
# 4        Scikit-learn ,  TensorFlow , Keras , RandomF...
# 5        Scikit-learn ,,, RandomForest, Xgboost ,,, L...
# 6        Scikit-learn ,  TensorFlow , Keras , RandomF...
# 7        Scikit-learn ,  TensorFlow , Keras ,,, PyTor...
# ...                                                  ...
# 19570                                        ,,,,,,,,,,,
# 19604                                        ,,,,,,,,,,,
# 19664       Scikit-learn ,  TensorFlow , Keras ,,,,,,,,,
# 19691     Scikit-learn ,  TensorFlow ,,,, PyTorch ,,,,,,
# 19717               Scikit-learn ,,,,,,,, Spark MLib ,,,
#
#                                              ML_Products
# 1                                            ,,,,,,,,,,,
# 4               ,,Azure Machine Learning Studio,,,,,,,,,
# 5                                            ,,,,,,,,,,,
# 6                                  ,,,,,,,RapidMiner,,,,
# 7      SAS,,Azure Machine Learning Studio,Google Clou...
# ...                                                  ...
# 19570                                        ,,,,,,,,,,,
# 19604                                        ,,,,,,,,,,,
# 19664                                        ,,,,,,,,,,,
# 19691                                        ,,,,,,,,,,,
# 19717                                        ,,,,,,,,,,,
#
# [8936 rows x 24 columns]

# %%
df.to_csv(r'cleaned_multiple_choice_responses.csv')
