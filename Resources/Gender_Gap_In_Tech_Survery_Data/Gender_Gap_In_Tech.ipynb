# %%
import pandas as pd

df = pd.read_csv("multiple_choice_responses.csv", index_col=False)
df.head()
# Out:
# C:\Users\snkty\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (0,3,7,19,34,47,49,50,51,52,53,54,68,81,94,96,109,115,130,139,147,154,167,180,193,206,219,232,245) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
# 1                                 510                        22-24
# 2                                 423                        40-44
# 3                                  83                        55-59
# 4                                 391                        40-44
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                    Male
# 2                                    Male
# 3                                  Female
# 4                                    Male
#
#                                        Q2_OTHER_TEXT  \
# 0  What is your gender? - Prefer to self-describe...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# 4                                                 -1
#
#                                           Q3  \
# 0  In which country do you currently reside?
# 1                                     France
# 2                                      India
# 3                                    Germany
# 4                                  Australia
#
#                                                   Q4  \
# 0  What is the highest level of formal education ...
# 1                                    Master’s degree
# 2                                Professional degree
# 3                                Professional degree
# 4                                    Master’s degree
#
#                                                   Q5  \
# 0  Select the title most similar to your current ...
# 1                                  Software Engineer
# 2                                  Software Engineer
# 3                                                NaN
# 4                                              Other
#
#                                        Q5_OTHER_TEXT  \
# 0  Select the title most similar to your current ...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# 4                                                  0
#
#                                                   Q6  \
# 0  What is the size of the company where you are ...
# 1                               1000-9,999 employees
# 2                                 > 10,000 employees
# 3                                                NaN
# 4                                 > 10,000 employees
#
#                                                   Q7  ...  \
# 0  Approximately how many individuals are respons...  ...
# 1                                                  0  ...
# 2                                                20+  ...
# 3                                                NaN  ...
# 4                                                20+  ...
#
#                                           Q34_Part_4  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q34_Part_5  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q34_Part_6  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q34_Part_7  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q34_Part_8  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q34_Part_9  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                 Azure SQL Database
#
#                                          Q34_Part_10  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Q34_Part_11  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Q34_Part_12  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                       Q34_OTHER_TEXT
# 0  Which of the following relational database pro...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# 4                                                 -1
#
# [5 rows x 246 columns]

# %%
# Way too many columns
df = df[['Q1',
         'Q2', 
         'Q3',
         'Q4', 
         'Q5', 
         'Q6',
         'Q7',
         'Q8',
         'Q9_Part_1',
         'Q9_Part_2',
         'Q9_Part_3',
         'Q9_Part_4',
         'Q9_Part_5',
         'Q9_Part_6',
         'Q9_Part_7',
         'Q10',
         'Q11',
         'Q12_Part_1',
         'Q12_Part_2',
         'Q12_Part_3',
         'Q12_Part_4',
         'Q12_Part_5',
         'Q12_Part_6',
         'Q12_Part_7',
         'Q12_Part_8',
         'Q12_Part_9',
         'Q12_Part_10',
         'Q12_Part_11',
         'Q12_Part_12',
         'Q13_Part_1',
         'Q13_Part_2',
         'Q13_Part_3',
         'Q13_Part_4',
         'Q13_Part_5',
         'Q13_Part_6',
         'Q13_Part_7',
         'Q13_Part_8',
         'Q13_Part_9',
         'Q13_Part_10',
         'Q13_Part_11',
         'Q13_Part_12',
         'Q14',
         'Q16_Part_1',
         'Q16_Part_2',
         'Q16_Part_3',
         'Q16_Part_4',
         'Q16_Part_5',
         'Q16_Part_6',
         'Q16_Part_7',
         'Q16_Part_8',
         'Q16_Part_9',
         'Q16_Part_10',
         'Q16_Part_11',
         'Q16_Part_12',
         'Q17_Part_1',
         'Q17_Part_2',
         'Q17_Part_3',
         'Q17_Part_4',
         'Q17_Part_5',
         'Q17_Part_6',
         'Q17_Part_7',
         'Q17_Part_8',
         'Q17_Part_9',
         'Q17_Part_10',
         'Q17_Part_11',
         'Q17_Part_12',
         'Q18_Part_1',
         'Q18_Part_2',
         'Q18_Part_3',
         'Q18_Part_4',
         'Q18_Part_5',
         'Q18_Part_6',
         'Q18_Part_7',
         'Q18_Part_8',
         'Q18_Part_9',
         'Q18_Part_10',
         'Q18_Part_11',
         'Q18_Part_12',
         'Q19',
         'Q20_Part_1',
         'Q20_Part_2',
         'Q20_Part_3',
         'Q20_Part_4',
         'Q20_Part_5',
         'Q20_Part_6',
         'Q20_Part_7',
         'Q20_Part_8',
         'Q20_Part_9',
         'Q20_Part_10',
         'Q20_Part_11',
         'Q20_Part_12',
         'Q23',
         'Q24_Part_1',
         'Q24_Part_2',
         'Q24_Part_3',
         'Q24_Part_4',
         'Q24_Part_5',
         'Q24_Part_6',
         'Q24_Part_7',
         'Q24_Part_8',
         'Q24_Part_9',
         'Q24_Part_10',
         'Q24_Part_11',
         'Q24_Part_12',
         'Q25_Part_1',
         'Q25_Part_2',
         'Q25_Part_3',
         'Q25_Part_4',
         'Q25_Part_5',
         'Q25_Part_6',
         'Q25_Part_7',
         'Q25_Part_8',
         'Q27_Part_1',
         'Q27_Part_2',
         'Q27_Part_3',
         'Q27_Part_4',
         'Q27_Part_5',
         'Q27_Part_6',
         'Q28_Part_1',
         'Q28_Part_2',
         'Q28_Part_3',
         'Q28_Part_4',
         'Q28_Part_5',
         'Q28_Part_6',
         'Q28_Part_7',
         'Q28_Part_8',
         'Q28_Part_9',
         'Q28_Part_10',
         'Q28_Part_11',
         'Q28_Part_12',
         'Q32_Part_1',
         'Q32_Part_2',
         'Q32_Part_3',
         'Q32_Part_4',
         'Q32_Part_5',
         'Q32_Part_6',
         'Q32_Part_7',
         'Q32_Part_8',
         'Q32_Part_9',
         'Q32_Part_10',
         'Q32_Part_11',
         'Q32_Part_12']]

# %%
# Rename Columns 
df.columns = ['age',
              'gender',
              'country',
              'education',
              'job_title',
              'company_size',
              'Number_Ppl_in_Workload',
              'ML_avaliable_at_company',
           'Q9_Part_1',
         'Q9_Part_2',
         'Q9_Part_3',
         'Q9_Part_4',
         'Q9_Part_5',
         'Q9_Part_6',
         'Q9_Part_7',
         'Q9_Part_8',
              'Salary',
              'ML_expenses'
              'Q12_Part_1',
         'Q12_Part_2',
         'Q12_Part_3',
         'Q12_Part_4',
         'Q12_Part_5',
         'Q12_Part_6',
         'Q12_Part_7',
         'Q12_Part_8',
         'Q12_Part_9',
         'Q12_Part_10',
         'Q12_Part_11',
         'Q12_Part_12',
         'Q13_Part_1',
         'Q13_Part_2',
         'Q13_Part_3',
         'Q13_Part_4',
         'Q13_Part_5',
         'Q13_Part_6',
         'Q13_Part_7',
         'Q13_Part_8',
         'Q13_Part_9',
         'Q13_Part_10',
         'Q13_Part_11',
         'Q13_Part_12',
              'Tool_to_analyze_data',
              'Q16_Part_1',
         'Q16_Part_2',
         'Q16_Part_3',
         'Q16_Part_4',
         'Q16_Part_5',
         'Q16_Part_6',
         'Q16_Part_7',
         'Q16_Part_8',
         'Q16_Part_9',
         'Q16_Part_10',
         'Q16_Part_11',
         'Q16_Part_12',
         'Q17_Part_1',
         'Q17_Part_2',
         'Q17_Part_3',
         'Q17_Part_4',
         'Q17_Part_5',
         'Q17_Part_6',
         'Q17_Part_7',
         'Q17_Part_8',
         'Q17_Part_9',
         'Q17_Part_10',
         'Q17_Part_11',
         'Q17_Part_12',
         'Q18_Part_1',
         'Q18_Part_2',
         'Q18_Part_3',
         'Q18_Part_4',
         'Q18_Part_5',
         'Q18_Part_6',
         'Q18_Part_7',
         'Q18_Part_8',
         'Q18_Part_9',
         'Q18_Part_10',
         'Q18_Part_11',
         'Q18_Part_12',
         'Q19',
         'Q20_Part_1',
         'Q20_Part_2',
         'Q20_Part_3',
         'Q20_Part_4',
         'Q20_Part_5',
         'Q20_Part_6',
         'Q20_Part_7',
         'Q20_Part_8',
         'Q20_Part_9',
         'Q20_Part_10',
         'Q20_Part_11',
         'Q20_Part_12',
              'Years_ML',
              'Q24_Part_1',
         'Q24_Part_2',
         'Q24_Part_3',
         'Q24_Part_4',
         'Q24_Part_5',
         'Q24_Part_6',
         'Q24_Part_7',
         'Q24_Part_8',
         'Q24_Part_9',
         'Q24_Part_10',
         'Q24_Part_11',
         'Q24_Part_12',
         'Q25_Part_1',
         'Q25_Part_2',
         'Q25_Part_3',
         'Q25_Part_4',
         'Q25_Part_5',
         'Q25_Part_6',
         'Q25_Part_7',
         'Q25_Part_8',
         'Q27_Part_1',
         'Q27_Part_2',
         'Q27_Part_3',
         'Q27_Part_4',
         'Q27_Part_5',
         'Q27_Part_6',
         'Q28_Part_1',
         'Q28_Part_2',
         'Q28_Part_3',
         'Q28_Part_4',
         'Q28_Part_5',
         'Q28_Part_6',
         'Q28_Part_7',
         'Q28_Part_8',
         'Q28_Part_9',
         'Q28_Part_10',
         'Q28_Part_11',
         'Q28_Part_12',
         'Q32_Part_1',
         'Q32_Part_2',
         'Q32_Part_3',
         'Q32_Part_4',
         'Q32_Part_5',
         'Q32_Part_6',
         'Q32_Part_7',
         'Q32_Part_8',
         'Q32_Part_9',
         'Q32_Part_10',
         'Q32_Part_11',
         'Q32_Part_12']
         
              
df
# Out:
#                                age                                  gender  \
# 0      What is your age (# years)?  What is your gender? - Selected Choice
# 1                            22-24                                    Male
# 2                            40-44                                    Male
# 3                            55-59                                  Female
# 4                            40-44                                    Male
# ...                            ...                                     ...
# 19713                        50-54                                    Male
# 19714                        18-21                                    Male
# 19715                        35-39                                    Male
# 19716                        25-29                                    Male
# 19717                        50-54                                    Male
#
#                                          country  \
# 0      In which country do you currently reside?
# 1                                         France
# 2                                          India
# 3                                        Germany
# 4                                      Australia
# ...                                          ...
# 19713                                      Japan
# 19714                                      India
# 19715                                      India
# 19716                                      India
# 19717                                     France
#
#                                                education  \
# 0      What is the highest level of formal education ...
# 1                                        Master’s degree
# 2                                    Professional degree
# 3                                    Professional degree
# 4                                        Master’s degree
# ...                                                  ...
# 19713                                                NaN
# 19714                                  Bachelor’s degree
# 19715                                    Master’s degree
# 19716                                    Master’s degree
# 19717                                  Bachelor’s degree
#
#                                                job_title  \
# 0      Select the title most similar to your current ...
# 1                                      Software Engineer
# 2                                      Software Engineer
# 3                                                    NaN
# 4                                                  Other
# ...                                                  ...
# 19713                                                NaN
# 19714                                              Other
# 19715                                            Student
# 19716                                       Statistician
# 19717                                  Software Engineer
#
#                                             company_size  \
# 0      What is the size of the company where you are ...
# 1                                   1000-9,999 employees
# 2                                     > 10,000 employees
# 3                                                    NaN
# 4                                     > 10,000 employees
# ...                                                  ...
# 19713                                                NaN
# 19714                                  250-999 employees
# 19715                                                NaN
# 19716                                   50-249 employees
# 19717                                 > 10,000 employees
#
#                                   Number_Ppl_in_Workload  \
# 0      Approximately how many individuals are respons...
# 1                                                      0
# 2                                                    20+
# 3                                                    NaN
# 4                                                    20+
# ...                                                  ...
# 19713                                                NaN
# 19714                                                3-4
# 19715                                                NaN
# 19716                                              15-19
# 19717                                                20+
#
#                                  ML_avaliable_at_company  \
# 0      Does your current employer incorporate machine...
# 1                                          I do not know
# 2      We have well established ML methods (i.e., mod...
# 3                                                    NaN
# 4                                          I do not know
# ...                                                  ...
# 19713                                                NaN
# 19714                                      I do not know
# 19715                                                NaN
# 19716  We recently started using ML methods (i.e., mo...
# 19717  We have well established ML methods (i.e., mod...
#
#                                                Q9_Part_1  \
# 0      Select any activities that make up an importan...
# 1                                                    NaN
# 2      Analyze and understand data to influence produ...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19713                                                NaN
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
#
#                                                Q9_Part_2  ...  \
# 0      Select any activities that make up an importan...  ...
# 1                                                    NaN  ...
# 2      Build and/or run the data infrastructure that ...  ...
# 3                                                    NaN  ...
# 4                                                    NaN  ...
# ...                                                  ...  ...
# 19713                                                NaN  ...
# 19714                                                NaN  ...
# 19715                                                NaN  ...
# 19716                                                NaN  ...
# 19717  Build and/or run the data infrastructure that ...  ...
#
#                                               Q32_Part_3  \
# 0      Which of the following machine learning produc...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                          Azure Machine Learning Studio
# ...                                                  ...
# 19713                                                NaN
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
#
#                                               Q32_Part_4  \
# 0      Which of the following machine learning produc...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19713                                                NaN
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
#
#                                               Q32_Part_5  \
# 0      Which of the following machine learning produc...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19713                                                NaN
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
#
#                                               Q32_Part_6  \
# 0      Which of the following machine learning produc...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19713                                                NaN
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
#
#                                               Q32_Part_7  \
# 0      Which of the following machine learning produc...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19713                                                NaN
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
#
#                                               Q32_Part_8  \
# 0      Which of the following machine learning produc...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19713                                                NaN
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
#
#                                               Q32_Part_9  \
# 0      Which of the following machine learning produc...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19713                                                NaN
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
#
#                                              Q32_Part_10  \
# 0      Which of the following machine learning produc...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19713                                                NaN
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
#
#                                              Q32_Part_11  \
# 0      Which of the following machine learning produc...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19713                                                NaN
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
#
#                                              Q32_Part_12
# 0      Which of the following machine learning produc...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19713                                                NaN
# 19714                                                NaN
# 19715                                                NaN
# 19716                                                NaN
# 19717                                                NaN
#
# [19718 rows x 142 columns]

# %%
# Combine multiple choice answers
df['Important_Role'] = df[df.columns[12:19]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['Media_sources'] = df[df.columns[23:34]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['Data_Science_Path'] = df[df.columns[36:47]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['IDEs'] = df[df.columns[57:68]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['Notebooks'] = df[df.columns[70:81]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['Languages'] = df[df.columns[83:94]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['Data_visualization_tools'] = df[df.columns[98:109 ]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['ML_alogrithms'] = df[df.columns[119:130]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['ML_tools'] = df[df.columns[132:139]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['NLP_language'] = df[df.columns[149:154]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['ML_frameworks'] = df[df.columns[156:157]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# Combine multiple choice answers
df['ML_products'] = df[df.columns[208:219]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)

# %%
for col in df.columns:
    if 'Part' in col:
        del df[col]

# %%
df = df.dropna()

# %%
Women_df = df[df['gender'] == 'Female']
Women_df
# Out:
#          age  gender                   country          education  \
# 8      22-24  Female  United States of America  Bachelor’s degree
# 16     50-54  Female  United States of America    Master’s degree
# 21     22-24  Female                   Ireland    Master’s degree
# 29     30-34  Female                   Ukraine    Doctoral degree
# 30     25-29  Female                  Pakistan    Master’s degree
# ...      ...     ...                       ...                ...
# 19074  30-34  Female                     China    Master’s degree
# 19081  22-24  Female                     India    Master’s degree
# 19124  35-39  Female                    Brazil    Master’s degree
# 19465  25-29  Female                     Kenya    Master’s degree
# 19583  22-24  Female                     Other  Bachelor’s degree
#
#                 job_title          company_size Number_Ppl_in_Workload  \
# 8          Data Scientist    > 10,000 employees                    20+
# 16           Data Analyst      50-249 employees                    1-2
# 21           Data Analyst  1000-9,999 employees                  10-14
# 29     Research Scientist  1000-9,999 employees                    3-4
# 30     Research Scientist        0-49 employees                  10-14
# ...                   ...                   ...                    ...
# 19074      Data Scientist      50-249 employees                    5-9
# 19081        Data Analyst    > 10,000 employees                    5-9
# 19124               Other      50-249 employees                      0
# 19465        Data Analyst    > 10,000 employees                    1-2
# 19583               Other      50-249 employees                    1-2
#
#                                  ML_avaliable_at_company             Salary  \
# 8      We recently started using ML methods (i.e., mo...           $0 (USD)
# 16     We use ML methods for generating insights (but...  > $100,000 ($USD)
# 21     We are exploring ML methods (and may one day p...  > $100,000 ($USD)
# 29                         No (we do not use ML methods)             $1-$99
# 30     We use ML methods for generating insights (but...           $0 (USD)
# ...                                                  ...                ...
# 19074  We recently started using ML methods (i.e., mo...       $1000-$9,999
# 19081  We recently started using ML methods (i.e., mo...           $0 (USD)
# 19124  We use ML methods for generating insights (but...          $100-$999
# 19465                      No (we do not use ML methods)           $0 (USD)
# 19583  We are exploring ML methods (and may one day p...          $100-$999
#
#                                     Tool_to_analyze_data  ...  \
# 8      Local development environments (RStudio, Jupyt...  ...
# 16     Basic statistical software (Microsoft Excel, G...  ...
# 21       Advanced statistical software (SPSS, SAS, etc.)  ...
# 29     Local development environments (RStudio, Jupyt...  ...
# 30     Local development environments (RStudio, Jupyt...  ...
# ...                                                  ...  ...
# 19074    Advanced statistical software (SPSS, SAS, etc.)  ...
# 19081    Advanced statistical software (SPSS, SAS, etc.)  ...
# 19124  Basic statistical software (Microsoft Excel, G...  ...
# 19465  Business intelligence software (Salesforce, Ta...  ...
# 19583  Local development environments (RStudio, Jupyt...  ...
#
#                                        Data_Science_Path  \
# 8      Udemy;University Courses (resulting in a unive...
# 16     Udemy;Other;Basic statistical software (Micros...
# 21     Udemy;Advanced statistical software (SPSS, SAS...
# 29     Local development environments (RStudio, Jupyt...
# 30     University Courses (resulting in a university ...
# ...                                                  ...
# 19074  Advanced statistical software (SPSS, SAS, etc....
# 19081  University Courses (resulting in a university ...
# 19124  Basic statistical software (Microsoft Excel, G...
# 19465  Business intelligence software (Salesforce, Ta...
# 19583  University Courses (resulting in a university ...
#
#                                                     IDEs  \
# 8      AWS Notebook Products (EMR Notebooks, Sagemake...
# 16                                         None;Python;R
# 21      Google Cloud Notebook Products (AI Platform, ...
# 29            Binder / JupyterHub ; IBM Watson Studio ;R
# 30                                           None;Python
# ...                                                  ...
# 19074                        Binder / JupyterHub ;Python
# 19081                                           Python;R
# 19124                                             Python
# 19465                        Binder / JupyterHub ;Python
# 19583                                             Python
#
#                                     Notebooks  \
# 8                         Python; Matplotlib
# 16        SQL; Ggplot / ggplot2 ; Matplotlib
# 21     Python; Ggplot / ggplot2 ; Matplotlib
# 29                       R; Ggplot / ggplot2
# 30                        Python; Matplotlib
# ...                                       ...
# 19074                                  Python
# 19081                     Python; Matplotlib
# 19124                     Python; Matplotlib
# 19465  Python; Ggplot / ggplot2 ; Matplotlib
# 19583                     Python; Matplotlib
#
#                                                Languages  \
# 8       Plotly / Plotly Express ;3-4 years;Linear or ...
# 16      Seaborn ;Other;1-2 years;Linear or Logistic R...
# 21      Seaborn ;1-2 years;Linear or Logistic Regress...
# 29               2-3 years;Linear or Logistic Regression
# 30                                             < 1 years
# ...                                                  ...
# 19074   Plotly / Plotly Express ;4-5 years;Linear or ...
# 19081   Plotly / Plotly Express ; Seaborn ;< 1 years;...
# 19124   Seaborn ;< 1 years;Linear or Logistic Regress...
# 19465                                 Seaborn ;2-3 years
# 19583   Seaborn ;1-2 years;Linear or Logistic Regress...
#
#                                 Data_visualization_tools  \
# 8                          Convolutional Neural Networks
# 16
# 21     Automated data augmentation (e.g. imgaug, albu...
# 29
# 30     None;Automated model selection (e.g. auto-skle...
# ...                                                  ...
# 19074  Automated feature engineering/selection (e.g. ...
# 19081
# 19124
# 19465
# 19583  Convolutional Neural Networks;Automated hyperp...
#
#                                     ML_alogrithms  \
# 8                TensorFlow ; Keras ; Spark MLib
# 16
# 21                      TensorFlow ; RandomForest
# 29                                           None
# 30
# ...                                           ...
# 19074   RandomForest; Xgboost ; Caret ; LightGBM
# 19081                                RandomForest
# 19124
# 19465
# 19583                       TensorFlow ; PyTorch
#
#                             ML_tools  \
# 8
# 16
# 21
# 29
# 30
# ...                              ...
# 19074  Google Cloud Natural Language
# 19081
# 19124
# 19465
# 19583
#
#                                             NLP_language ML_frameworks  \
# 8                      TensorFlow ; Keras ; Spark MLib ;
# 16                                                     ;
# 21                            TensorFlow ; RandomForest;
# 29                                                 None;
# 30                                                     ;
# ...                                                  ...           ...
# 19074   RandomForest; Xgboost ; Caret ; LightGBM ;Goo...
# 19081                                      RandomForest;
# 19124                                                  ;
# 19465                                                  ;
# 19583                             TensorFlow ; PyTorch ;
#
#       ML_products
# 8
# 16
# 21
# 29
# 30
# ...           ...
# 19074
# 19081
# 19124
# 19465
# 19583
#
# [1453 rows x 24 columns]

# %%
Men_df = df[df['gender'] == 'Male']
Men_df
# Out:
#          age gender    country               education           job_title  \
# 1      22-24   Male     France         Master’s degree   Software Engineer
# 4      40-44   Male  Australia         Master’s degree               Other
# 5      22-24   Male      India       Bachelor’s degree               Other
# 6      50-54   Male     France         Master’s degree      Data Scientist
# 7      22-24   Male      India         Master’s degree      Data Scientist
# ...      ...    ...        ...                     ...                 ...
# 19570  22-24   Male  Indonesia         Master’s degree  Research Scientist
# 19604  22-24   Male     Sweden         Master’s degree        Statistician
# 19664  25-29   Male      China  I prefer not to answer       Data Engineer
# 19691  25-29   Male  Australia       Bachelor’s degree               Other
# 19717  50-54   Male     France       Bachelor’s degree   Software Engineer
#
#                company_size Number_Ppl_in_Workload  \
# 1      1000-9,999 employees                      0
# 4        > 10,000 employees                    20+
# 5            0-49 employees                      0
# 6            0-49 employees                    3-4
# 7          50-249 employees                    20+
# ...                     ...                    ...
# 19570        0-49 employees                    3-4
# 19604  1000-9,999 employees                    5-9
# 19664     250-999 employees                    5-9
# 19691  1000-9,999 employees                    5-9
# 19717    > 10,000 employees                    20+
#
#                                  ML_avaliable_at_company           Salary  \
# 1                                          I do not know         $0 (USD)
# 4                                          I do not know  $10,000-$99,999
# 5                          No (we do not use ML methods)         $0 (USD)
# 6      We have well established ML methods (i.e., mod...  $10,000-$99,999
# 7      We are exploring ML methods (and may one day p...        $100-$999
# ...                                                  ...              ...
# 19570  We use ML methods for generating insights (but...        $100-$999
# 19604                      No (we do not use ML methods)         $0 (USD)
# 19664  We recently started using ML methods (i.e., mo...        $100-$999
# 19691                      No (we do not use ML methods)  $10,000-$99,999
# 19717  We have well established ML methods (i.e., mod...         $0 (USD)
#
#                                     Tool_to_analyze_data  ...  \
# 1      Basic statistical software (Microsoft Excel, G...  ...
# 4      Local development environments (RStudio, Jupyt...  ...
# 5      Local development environments (RStudio, Jupyt...  ...
# 6        Advanced statistical software (SPSS, SAS, etc.)  ...
# 7      Local development environments (RStudio, Jupyt...  ...
# ...                                                  ...  ...
# 19570  Local development environments (RStudio, Jupyt...  ...
# 19604  Local development environments (RStudio, Jupyt...  ...
# 19664  Local development environments (RStudio, Jupyt...  ...
# 19691  Local development environments (RStudio, Jupyt...  ...
# 19717  Local development environments (RStudio, Jupyt...  ...
#
#                                        Data_Science_Path  \
# 1      Udemy;Basic statistical software (Microsoft Ex...
# 4      University Courses (resulting in a university ...
# 5      Other;Local development environments (RStudio,...
# 6      None;Advanced statistical software (SPSS, SAS,...
# 7      Udemy;Local development environments (RStudio,...
# ...                                                  ...
# 19570  University Courses (resulting in a university ...
# 19604  Local development environments (RStudio, Jupyt...
# 19664  Local development environments (RStudio, Jupyt...
# 19691  Udemy;Local development environments (RStudio,...
# 19717  Udemy;Local development environments (RStudio,...
#
#                                                     IDEs  \
# 1                                          None;Python;R
# 4                                               Python;R
# 5       Google Cloud Notebook Products (AI Platform, ...
# 6                                          None;Python;R
# 7                          Binder / JupyterHub ;Python;R
# ...                                                  ...
# 19570  AWS Notebook Products (EMR Notebooks, Sagemake...
# 19604                                      None;Python;R
# 19664                                             Python
# 19691                                        None;Python
# 19717                          IBM Watson Studio ;Python
#
#                                                Notebooks  \
# 1             Java;Javascript;MATLAB;Python; Matplotlib
# 4            Bash;Python; Ggplot / ggplot2 ; Matplotlib
# 5                                    Python; Matplotlib
# 6                                Java; Ggplot / ggplot2
# 7                               Bash;Python; Matplotlib
# ...                                                  ...
# 19570  Javascript;Python; Ggplot / ggplot2 ; Matplotlib
# 19604      MATLAB;Python; Ggplot / ggplot2 ; Matplotlib
# 19664                                             Python
# 19691                         MATLAB;Python; Matplotlib
# 19717                      Java;Bash;Python; Matplotlib
#
#                                                Languages  \
# 1                1-2 years;Linear or Logistic Regression
# 4       Seaborn ;2-3 years;Linear or Logistic Regression
# 5       Plotly / Plotly Express ; Seaborn ;< 1 years;...
# 6      10-15 years;Linear or Logistic Regression;Deci...
# 7       Plotly / Plotly Express ; Bokeh ; Seaborn ;2-...
# ...                                                  ...
# 19570   D3.js ; Seaborn ; Leaflet / Folium ;< 1 years...
# 19604   Plotly / Plotly Express ;1-2 years;Linear or ...
# 19664                                 Seaborn ;1-2 years
# 19691   Plotly / Plotly Express ; Bokeh ; Seaborn ;1-...
# 19717  4-5 years;Linear or Logistic Regression;Decisi...
#
#                                 Data_visualization_tools  \
# 1
# 4                          Convolutional Neural Networks
# 5
# 6      Convolutional Neural Networks;Generative Adver...
# 7      Convolutional Neural Networks;Recurrent Neural...
# ...                                                  ...
# 19570  Convolutional Neural Networks;Generative Adver...
# 19604                      Convolutional Neural Networks
# 19664                          Recurrent Neural Networks
# 19691
# 19717  Automated model selection (e.g. auto-sklearn, ...
#
#                                            ML_alogrithms  \
# 1                                                   None
# 4                      TensorFlow ; Keras ; RandomForest
# 5                      RandomForest; Xgboost ; LightGBM
# 6        TensorFlow ; Keras ; RandomForest; Xgboost ;...
# 7                          TensorFlow ; Keras ; PyTorch
# ...                                                  ...
# 19570
# 19604
# 19664                                TensorFlow ; Keras
# 19691                              TensorFlow ; PyTorch
# 19717                                        Spark MLib
#
#                                                 ML_tools  \
# 1
# 4                          Azure Machine Learning Studio
# 5
# 6                                             RapidMiner
# 7      Azure Machine Learning Studio;Google Cloud Mac...
# ...                                                  ...
# 19570
# 19604
# 19664
# 19691
# 19717
#
#                                             NLP_language ML_frameworks  \
# 1                                                  None;
# 4        TensorFlow ; Keras ; RandomForest;Azure Mach...
# 5                     RandomForest; Xgboost ; LightGBM ;
# 6        TensorFlow ; Keras ; RandomForest; Xgboost ;...
# 7        TensorFlow ; Keras ; PyTorch ;Azure Machine ...
# ...                                                  ...           ...
# 19570                                                  ;
# 19604                                                  ;
# 19664                               TensorFlow ; Keras ;
# 19691                             TensorFlow ; PyTorch ;
# 19717                                       Spark MLib ;
#
#       ML_products
# 1
# 4
# 5
# 6
# 7
# ...           ...
# 19570
# 19604
# 19664
# 19691
# 19717
#
# [8936 rows x 24 columns]

# %%
df.to_csv(r"cleaned_multiple_choice_responses.csv")
