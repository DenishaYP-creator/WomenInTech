# %%
import pandas as pd

df = pd.read_csv("kaggle_survey_2020_responses.csv")
df.head()
# Out:
# C:\Users\snkty\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
# 1                                1838                        35-39
# 2                              289287                        30-34
# 3                                 860                        35-39
# 4                                 507                        30-34
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
# 2                                     Man
# 3                                     Man
# 4                                     Man
#
# ...

# %%
# Way too many columns
df = df[['Q1',
         'Q2', 
         'Q3',
         'Q4', 
         'Q5', 
         'Q6',
         'Q7_Part_1', 
         'Q7_Part_2', 
         'Q7_Part_3', 
         'Q7_Part_4',
         'Q7_Part_5',
         'Q7_Part_6',
         'Q7_Part_7',
         'Q7_Part_8', 
         'Q7_Part_9',
         'Q7_Part_10',
         'Q7_Part_11', 
         'Q7_Part_12',
         'Q9_Part_1',
         'Q9_Part_2',
         'Q9_Part_3',
         'Q9_Part_4',
         'Q9_Part_5',
         'Q9_Part_6',
         'Q9_Part_7',
         'Q9_Part_8',
         'Q9_Part_9',
         'Q9_Part_10',
         'Q9_Part_11',
         'Q10_Part_1',
         'Q10_Part_2',
         'Q10_Part_3',
         'Q10_Part_4',
         'Q10_Part_5',
         'Q10_Part_6',
         'Q10_Part_7',
         'Q10_Part_8',
         'Q10_Part_9',
         'Q10_Part_10',
         'Q10_Part_11',
         'Q10_Part_12',
         'Q10_Part_13',
         'Q14_Part_1',
         'Q14_Part_2',
         'Q14_Part_3',
         'Q14_Part_4',
         'Q14_Part_5',
         'Q14_Part_6',
         'Q14_Part_7',
         'Q14_Part_8',
         'Q14_Part_9',
         'Q14_Part_10',
         'Q14_Part_11',
         'Q15',
         'Q16_Part_1',
         'Q16_Part_2',
         'Q16_Part_3',
         'Q16_Part_4',
         'Q16_Part_5',
         'Q16_Part_6',
         'Q16_Part_7',
         'Q16_Part_8',
         'Q16_Part_9',
         'Q16_Part_10',
         'Q16_Part_11',
         'Q16_Part_12',
         'Q16_Part_13',
         'Q16_Part_14',
         'Q16_Part_15',
         'Q17_Part_1',
         'Q17_Part_2',
         'Q17_Part_3',
         'Q17_Part_4',
         'Q17_Part_5',
         'Q17_Part_6',
         'Q17_Part_7',
         'Q17_Part_8',
         'Q17_Part_9',
         'Q17_Part_10',
         'Q17_Part_11',
         'Q19_Part_1',
         'Q19_Part_2',
         'Q19_Part_3',
         'Q19_Part_4',
         'Q19_Part_5',
         'Q20',
         'Q21',
         'Q22',
         'Q23_Part_1',
         'Q23_Part_2',
         'Q23_Part_3',
         'Q23_Part_4',
         'Q23_Part_5',
         'Q23_Part_6',
         'Q23_Part_7',
         'Q24',
         'Q25',
         'Q28_A_Part_1',
         'Q28_A_Part_2',
         'Q28_A_Part_3',
         'Q28_A_Part_4',
         'Q28_A_Part_5',
         'Q28_A_Part_6',
         'Q28_A_Part_7',
         'Q28_A_Part_8',
         'Q28_A_Part_9',
         'Q28_A_Part_10',
         'Q35_A_Part_1',
         'Q35_A_Part_2',
         'Q35_A_Part_3',
         'Q35_A_Part_4',
         'Q35_A_Part_5',
         'Q35_A_Part_6',
         'Q35_A_Part_7',
         'Q35_A_Part_8',
         'Q35_A_Part_9',
         'Q35_A_Part_10',
         'Q37_Part_1',
         'Q37_Part_2',
         'Q37_Part_3',
         'Q37_Part_4',
         'Q37_Part_5',
         'Q37_Part_6',
         'Q37_Part_7',
         'Q37_Part_8',
         'Q37_Part_9',
         'Q37_Part_10',
         'Q37_Part_11',
         'Q39_Part_1',
         'Q39_Part_2',
         'Q39_Part_3',
         'Q39_Part_4',
         'Q39_Part_5',
         'Q39_Part_6',
         'Q39_Part_7',
         'Q39_Part_8',
         'Q39_Part_9',
         'Q39_Part_10',
         'Q39_Part_11']]

# %%
# Rename Columns 
df.columns = ['Age',
         'Gender', 
         'Country',
         'Education', 
         'Job_Title', 
         'Years_Coding',
         'Q7_Part_1', 
         'Q7_Part_2', 
         'Q7_Part_3', 
         'Q7_Part_4',
         'Q7_Part_5',
         'Q7_Part_6',
         'Q7_Part_7',
         'Q7_Part_8', 
         'Q7_Part_9',
         'Q7_Part_10',
         'Q7_Part_11', 
         'Q7_Part_12',
         'Q9_Part_1',
         'Q9_Part_2',
         'Q9_Part_3',
         'Q9_Part_4',
         'Q9_Part_5',
         'Q9_Part_6',
         'Q9_Part_7',
         'Q9_Part_8',
         'Q9_Part_9',
         'Q9_Part_10',
         'Q9_Part_11',
         'Q10_Part_1',
         'Q10_Part_2',
         'Q10_Part_3',
         'Q10_Part_4',
         'Q10_Part_5',
         'Q10_Part_6',
         'Q10_Part_7',
         'Q10_Part_8',
         'Q10_Part_9',
         'Q10_Part_10',
         'Q10_Part_11',
         'Q10_Part_12',
         'Q10_Part_13',
         'Q14_Part_1',
         'Q14_Part_2',
         'Q14_Part_3',
         'Q14_Part_4',
         'Q14_Part_5',
         'Q14_Part_6',
         'Q14_Part_7',
         'Q14_Part_8',
         'Q14_Part_9',
         'Q14_Part_10',
         'Q14_Part_11',
         'Years_of_ML',
         'Q16_Part_1',
         'Q16_Part_2',
         'Q16_Part_3',
         'Q16_Part_4',
         'Q16_Part_5',
         'Q16_Part_6',
         'Q16_Part_7',
         'Q16_Part_8',
         'Q16_Part_9',
         'Q16_Part_10',
         'Q16_Part_11',
         'Q16_Part_12',
         'Q16_Part_13',
         'Q16_Part_14',
         'Q16_Part_15',
         'Q17_Part_1',
         'Q17_Part_2',
         'Q17_Part_3',
         'Q17_Part_4',
         'Q17_Part_5',
         'Q17_Part_6',
         'Q17_Part_7',
         'Q17_Part_8',
         'Q17_Part_9',
         'Q17_Part_10',
         'Q17_Part_11',
         'Q19_Part_1',
         'Q19_Part_2',
         'Q19_Part_3',
         'Q19_Part_4',
         'Q19_Part_5',
         'Company_Size',
         'Work_Load_Size',
         'ML_Access',
         'Q23_Part_1',
         'Q23_Part_2',
         'Q23_Part_3',
         'Q23_Part_4',
         'Q23_Part_5',
         'Q23_Part_6',
         'Q23_Part_7',
         'Salary',
         'Money_Spent_on_ML',
         'Q28_A_Part_1',
         'Q28_A_Part_2',
         'Q28_A_Part_3',
         'Q28_A_Part_4',
         'Q28_A_Part_5',
         'Q28_A_Part_6',
         'Q28_A_Part_7',
         'Q28_A_Part_8',
         'Q28_A_Part_9',
         'Q28_A_Part_10',
         'Q35_A_Part_1',
         'Q35_A_Part_2',
         'Q35_A_Part_3',
         'Q35_A_Part_4',
         'Q35_A_Part_5',
         'Q35_A_Part_6',
         'Q35_A_Part_7',
         'Q35_A_Part_8',
         'Q35_A_Part_9',
         'Q35_A_Part_10',
         'Q37_Part_1',
         'Q37_Part_2',
         'Q37_Part_3',
         'Q37_Part_4',
         'Q37_Part_5',
         'Q37_Part_6',
         'Q37_Part_7',
         'Q37_Part_8',
         'Q37_Part_9',
         'Q37_Part_10',
         'Q37_Part_11',
         'Q39_Part_1',
         'Q39_Part_2',
         'Q39_Part_3',
         'Q39_Part_4',
         'Q39_Part_5',
         'Q39_Part_6',
         'Q39_Part_7',
         'Q39_Part_8',
         'Q39_Part_9',
         'Q39_Part_10',
         'Q39_Part_11']

# %%
#Combine Mulitple Choice Answers
df['Programming_Langauges'] = df [['Q7_Part_1',
                                   'Q7_Part_2',
                                   'Q7_Part_3',
                                   'Q7_Part_4',
                                   'Q7_Part_5',
                                   'Q7_Part_6',
                                   'Q7_Part_7',
                                   'Q7_Part_8',
                                   'Q7_Part_9',
                                   'Q7_Part_10',
                                   'Q7_Part_11']].apply(lambda x: ','.join(x.astype(str).replace(['nan', 'None'], '')), axis = 1)


df['IDEs'] = df [['Q9_Part_1',
                  'Q9_Part_2',
                  'Q9_Part_3',
                  'Q9_Part_4',
                  'Q9_Part_5',
                  'Q9_Part_6',
                  'Q9_Part_7',
                  'Q9_Part_8',
                  'Q9_Part_9',
                  'Q9_Part_10',
                  'Q9_Part_11']].apply(lambda x: ','.join(x.astype(str).replace(['nan', 'None'], '')), axis = 1)


df['Notebooks'] = df [['Q10_Part_1',
                       'Q10_Part_2',
                       'Q10_Part_3',
                       'Q10_Part_4',
                       'Q10_Part_5',
                       'Q10_Part_6',
                       'Q10_Part_7',
                       'Q10_Part_8',
                       'Q10_Part_9',
                       'Q10_Part_10',
                       'Q10_Part_11',
                       'Q10_Part_12',
                       'Q10_Part_13']].apply(lambda x: ','.join(x.astype(str).replace(['nan', 'None'], '')), axis = 1)


df['data_visualization'] = df[['Q14_Part_1',
                               'Q14_Part_2',
                               'Q14_Part_3',
                               'Q14_Part_4',
                               'Q14_Part_5',
                               'Q14_Part_6',
                               'Q14_Part_7',
                               'Q14_Part_8',
                               'Q14_Part_9',
                               'Q14_Part_10',
                               'Q14_Part_11']].apply(lambda x: ','.join(x.astype(str).replace(['nan', 'None'], '')), axis = 1)


df['ML_frameworks'] = df[['Q16_Part_1',
                 'Q16_Part_2',
                 'Q16_Part_3',
                 'Q16_Part_4',
                 'Q16_Part_5',
                 'Q16_Part_6',
                 'Q16_Part_7',
                 'Q16_Part_8',
                 'Q16_Part_9',
                 'Q16_Part_10',
                 'Q16_Part_11',
                 'Q16_Part_12',
                 'Q16_Part_13',
                 'Q16_Part_14',
                 'Q16_Part_15']].apply(lambda x: ','.join(x.astype(str).replace(['nan', 'None'], '')), axis = 1)



df['ML_algorithms'] = df[['Q17_Part_1',
                      'Q17_Part_2',
                      'Q17_Part_3',
                      'Q17_Part_4',
                      'Q17_Part_5',
                      'Q17_Part_6',
                      'Q17_Part_7',
                      'Q17_Part_8',
                      'Q17_Part_9',
                      'Q17_Part_10',
                      'Q17_Part_11']].apply(lambda x: ','.join(x.astype(str).replace(['nan', 'None'], '')), axis = 1)


df['NLP'] = df[['Q19_Part_1',
                'Q19_Part_2',
                'Q19_Part_3',
                'Q19_Part_4',
                'Q19_Part_5']].apply(lambda x: ','.join(x.astype(str).replace(['nan', 'None'], '')), axis = 1)


df['Important_Roles'] = df[['Q23_Part_1',
                          'Q23_Part_2',
                          'Q23_Part_3',
                          'Q23_Part_4',
                          'Q23_Part_5',
                          'Q23_Part_6',
                          'Q23_Part_7',]].apply(lambda x: ','.join(x.astype(str).replace(['nan', 'None'], '')), axis = 1)

df['ML_Products'] = df[['Q28_A_Part_1',
                        'Q28_A_Part_2',
                        'Q28_A_Part_3',
                        'Q28_A_Part_4',
                        'Q28_A_Part_5',
                        'Q28_A_Part_6',
                        'Q28_A_Part_7',
                        'Q28_A_Part_8',
                        'Q28_A_Part_9',
                        'Q28_A_Part_10']].apply(lambda x: ','.join(x.astype(str).replace(['nan', 'None'], '')), axis = 1)


df['ML_Tools'] = df[['Q35_A_Part_1',
                   'Q35_A_Part_2',
                   'Q35_A_Part_3',
                   'Q35_A_Part_4',
                   'Q35_A_Part_5',
                   'Q35_A_Part_6',
                   'Q35_A_Part_7',
                   'Q35_A_Part_8',
                   'Q35_A_Part_9',
                   'Q35_A_Part_10',]].apply(lambda x: ','.join(x.astype(str).replace(['nan', 'None'], '')), axis = 1)

df['Data_Science_Path']  = df[['Q37_Part_1',
                               'Q37_Part_2',
                               'Q37_Part_3',
                               'Q37_Part_4',
                               'Q37_Part_5',
                               'Q37_Part_6',
                               'Q37_Part_7',
                               'Q37_Part_8',
                               'Q37_Part_9',
                               'Q37_Part_10',
                               'Q37_Part_11']].apply(lambda x: ','.join(x.astype(str).replace(['nan', 'None'], '')), axis = 1)


df['Media_sources'] = df[['Q39_Part_1',
                          'Q39_Part_2',
                          'Q39_Part_3',
                          'Q39_Part_4',
                          'Q39_Part_5',
                          'Q39_Part_6',
                          'Q39_Part_7',
                          'Q39_Part_8',
                          'Q39_Part_9',
                          'Q39_Part_10',
                          'Q39_Part_11']].apply(lambda x: ','.join(x.astype(str).replace(['nan', 'None'], '')), axis = 1)

# %%
# Delete Individial Answer Columns
for col in df.columns:
    if 'Part' in col:
        del df[col]

# %%
#Drop NAN Values
df = df.dropna()

# %%
Women_df = df[df['Gender'] == 'Woman']
Women_df
# Out:
#          Age Gender    Country  \
# 21     22-24  Woman      India
# 23     55-59  Woman     Canada
# 31     35-39  Woman   Pakistan
# 45     25-29  Woman    Belarus
# 61     18-21  Woman  Indonesia
# ...      ...    ...        ...
# 19972  30-34  Woman      Kenya
# 19983  22-24  Woman    Ireland
# 19998  22-24  Woman    Romania
# 20008  22-24  Woman      India
# 20014  30-34  Woman     Turkey
#
#                                                Education  \
# 21                                       Doctoral degree
# 23                                       Master’s degree
# 31                                       Master’s degree
# 45                                       Master’s degree
# 61                                     Bachelor’s degree
# ...                                                  ...
# 19972                                    Master’s degree
# 19983  Some college/university study without earning ...
# 19998                                    Master’s degree
# ...

# %%
Men_df = df[df['Gender'] == 'Man']
Men_df
# Out:
#          Age Gender                   Country               Education  \
# 2      30-34    Man  United States of America         Master’s degree
# 3      35-39    Man                 Argentina       Bachelor’s degree
# 4      30-34    Man  United States of America         Master’s degree
# 9      35-39    Man                   Germany         Doctoral degree
# 12     35-39    Man  United States of America         Doctoral degree
# ...      ...    ...                       ...                     ...
# 20025  35-39    Man                  Malaysia  I prefer not to answer
# 20030  35-39    Man                  Thailand       Bachelor’s degree
# 20034  30-34    Man                    Brazil         Master’s degree
# 20035  22-24    Man                     India       Bachelor’s degree
# 20036  22-24    Man                  Pakistan         Master’s degree
#
#                        Job_Title Years_Coding  \
# 2                  Data Engineer   5-10 years
# ...

# %%
df.to_csv(r"clean_kaggle_survey_2020_responses1.csv")
