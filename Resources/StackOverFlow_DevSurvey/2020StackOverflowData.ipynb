# %% [markdown]
# # 2020 Stack Flow Developer Survey Data Set

# %% [markdown]
# # ETL

# %% [markdown]
# ####  Import Dependencies

# %%
import pandas as pd

# %% [markdown]
# ####  Load the data set

# %%
#Load the data set 
filepath = "../ResourcesStackOverFlow_DevSurveyResources-CsvFiles/survey_results_public.csv"
data= pd.read_csv(filepath, index_col=0)
#df= pd.read_csv(filepath)
data.head(3)

#ResourcesStackOverFlow_DevSurveyResources-CsvFiles
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-297ee5123706> in <module>
#       1 #Load the data set
#       2 filepath = "../ResourcesStackOverFlow_DevSurveyResources-CsvFiles/survey_results_public.csv"
# ----> 3 data= pd.read_csv(filepath, index_col=0)
#       4 #df= pd.read_csv(filepath)
#       5 data.head(3)
#
# ...

# %%
#View Columns
data.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq', 'CompTotal',
#        'ConvertedComp', 'Country', 'CurrencyDesc', 'CurrencySymbol',
#        'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel',
#        'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %% [markdown]
# #### Drop uncessary columns

# %%
# Drop uncessary columns 
df = data.drop(
    ['CompFreq','CompTotal',
     'CurrencyDesc', 
     'CurrencySymbol',
     'DatabaseDesireNextYear',
     'LanguageDesireNextYear',
     'MiscTechDesireNextYear',
        'NEWDevOps', 'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith',
       'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
       'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
       'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
       'NEWStuck',
     'PlatformDesireNextYear',
     'PurchaseWhat',  
     'SOVisitFreq', 
     'SurveyEase', 
     'SurveyLength',
     'WebframeDesireNextYear',
     
       ], axis=1)#.dropna()
df.head(3)
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode  \
# Respondent
# 1           I am a developer by profession      Yes  NaN         13
# 2           I am a developer by profession       No  NaN         19
# 3              I code primarily as a hobby      Yes  NaN         15
#
#             ConvertedComp             Country  \
# Respondent
# 1                     NaN             Germany
# 2                     NaN      United Kingdom
# 3                     NaN  Russian Federation
#
#                                    DatabaseWorkedWith  \
# Respondent
# 1           Elasticsearch;Microsoft SQL Server;Oracle
# 2                                                 NaN
# 3                                                 NaN
#
#                                                       DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# 2                     Developer, full-stack;Developer, mobile
# ...

# %%
#View Column Names 
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'ConvertedComp',
#        'Country', 'DatabaseWorkedWith', 'DevType', 'EdLevel', 'Employment',
#        'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageWorkedWith', 'MiscTechWorkedWith', 'OpSys', 'OrgSize',
#        'PlatformWorkedWith', 'Sexuality', 'SOAccount', 'SOComm', 'SOPartFreq',
#        'Trans', 'UndergradMajor', 'WebframeWorkedWith', 'WelcomeChange',
#        'WorkWeekHrs', 'YearsCode', 'YearsCodePro'],
#       dtype='object')

# %%
#Select only the data with the country United States & Drop Null Values 
us_df = df[(df['Country'] == 'United States')].dropna()
us_df.head(2)
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 8           I am a developer by profession      Yes  36.0         12
# 14          I am a developer by profession      Yes  27.0         13
#
#             ConvertedComp        Country             DatabaseWorkedWith  \
# Respondent
# 8                116000.0  United States            MariaDB;MySQL;Redis
# 14                66000.0  United States  Firebase;Microsoft SQL Server
#
#                                                       DevType  \
# Respondent
# 8           Developer, back-end;Developer, desktop or ente...
# 14          Developer, desktop or enterprise applications;...
#
#                                                  EdLevel          Employment  \
# Respondent
# 8           Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Employed full-time
# 14                   Associate degree (A.A., A.S., etc.)  Employed full-time
#
#             ... SOAccount           SOComm  \
# ...

# %%
#Check for Null Values
for column in us_df.columns:
    print(f"Column {column} has {us_df[column].isnull().sum()} null values")
# Out:
# Column MainBranch has 0 null values
# Column Hobbyist has 0 null values
# Column Age has 0 null values
# Column Age1stCode has 0 null values
# Column ConvertedComp has 0 null values
# Column Country has 0 null values
# Column DatabaseWorkedWith has 0 null values
# Column DevType has 0 null values
# Column EdLevel has 0 null values
# Column Employment has 0 null values
# Column Ethnicity has 0 null values
# Column Gender has 0 null values
# Column JobFactors has 0 null values
# Column JobSat has 0 null values
# Column JobSeek has 0 null values
# Column LanguageWorkedWith has 0 null values
# Column MiscTechWorkedWith has 0 null values
# Column OpSys has 0 null values
# Column OrgSize has 0 null values
# Column PlatformWorkedWith has 0 null values
# Column Sexuality has 0 null values
# Column SOAccount has 0 null values
# Column SOComm has 0 null values
# Column SOPartFreq has 0 null values
# Column Trans has 0 null values
# Column UndergradMajor has 0 null values
# ...

# %%
# ### Select gender Column 
gender= us_df['Gender']
gender
# Out:
# Respondent
# 8          Man
# 14         Man
# 19         Man
# 42         Man
# 49         Man
#          ...
# 62863      Man
# 62871      Man
# 62886      Man
# 62904      Man
# 62913    Woman
# Name: Gender, Length: 2857, dtype: object

# %%
### Select gender equal to women Column 
women= us_df[(us_df ['Gender'] == 'Woman')]
women
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 128                            I am a developer by profession      Yes  23.0
# 139                            I am a developer by profession       No  30.0
# 252                            I am a developer by profession      Yes  27.0
# 326                            I am a developer by profession      Yes  21.0
# 466                            I am a developer by profession      Yes  25.0
# ...                                                       ...      ...   ...
# 61594                          I am a developer by profession       No  59.0
# 62044                          I am a developer by profession      Yes  56.0
# 62715                          I am a developer by profession       No  60.0
# 62803                          I am a developer by profession      Yes  44.0
# 62913       I am not primarily a developer, but I write co...       No  33.0
#
# ...

# %%
# Select only the data with the gender equal to "Man"
men= us_df[(us_df ['Gender'] == 'Man')]
men
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 8           I am a developer by profession      Yes  36.0         12
# 14          I am a developer by profession      Yes  27.0         13
# 19          I am a developer by profession       No  24.0         15
# 42          I am a developer by profession       No  32.0         14
# 49          I am a developer by profession       No  23.0         15
# ...                                    ...      ...   ...        ...
# 62860       I am a developer by profession      Yes  52.0         11
# 62863       I am a developer by profession      Yes  30.0         11
# 62871       I am a developer by profession      Yes  34.0         16
# 62886       I am a developer by profession      Yes  32.0         24
# 62904       I am a developer by profession      Yes  33.0         24
#
#             ConvertedComp        Country  \
# Respondent
# 8                116000.0  United States
# ...

# %%
# Drop uncessary columns  
women_df = women.drop(
    ['Country', 'DatabaseWorkedWith','DevType', 'JobFactors', 'JobSat', 'JobSeek',
       'LanguageWorkedWith', 'MiscTechWorkedWith', 'OpSys','OrgSize','PlatformWorkedWith', 'Sexuality', 
       'SOAccount', 'SOComm', 'SOPartFreq',
       'Trans', 'WebframeWorkedWith', 'WelcomeChange',
       'WorkWeekHrs', ], axis=1)#.dropna()
women_df.head(3)
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 128         I am a developer by profession      Yes  23.0         14
# 139         I am a developer by profession       No  30.0         17
# 252         I am a developer by profession      Yes  27.0         12
#
#             ConvertedComp                                            EdLevel  \
# Respondent
# 128               80000.0  Some college/university study without earning ...
# 139               45000.0       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 252              122780.0       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                     Employment                     Ethnicity Gender  \
# Respondent
# 128         Employed full-time  White or of European descent  Woman
# 139         Employed full-time  White or of European descent  Woman
# 252         Employed full-time  White or of European descent  Woman
#
# ...

# %%
women_df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'ConvertedComp',
#        'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'UndergradMajor',
#        'YearsCode', 'YearsCodePro'],
#       dtype='object')

# %%
women_df.dtypes
# Out:
# MainBranch         object
# Hobbyist           object
# Age               float64
# Age1stCode         object
# ConvertedComp     float64
# EdLevel            object
# Employment         object
# Ethnicity          object
# Gender             object
# UndergradMajor     object
# YearsCode          object
# YearsCodePro       object
# dtype: object

# %%
# Save New cleaned File 
output_file_path = "../Resources/2020StackOverFlow_DevSurvey/clean_survey_results_public.csv""]
us_df.to_csv(output_file_path, index=False)
